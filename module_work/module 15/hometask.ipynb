# %%
import pickle
import pandas as pd
import implicit
import lightfm
import scipy

import string
# Библиотека построения индекса приближенного поиска ближайших соседей
import annoy
import numpy as np

from pymorphy2 import MorphAnalyzer
from stop_words import get_stop_words
from gensim.models import FastText
from tqdm import tqdm_notebook

from sklearn.model_selection import train_test_split
# Out:
# c:\study\venv\lib\site-packages\lightfm\_lightfm_fast.py:9: UserWarning: LightFM was compiled without OpenMP support. Only a single thread will be used.
#   warnings.warn(

# %%
# Для фильтрации пунктуации
exclude = set(string.punctuation)
# Для приведения слов в начальной форме
morpher = MorphAnalyzer()

# Для фильтрации стоп-слов
sw = get_stop_words("ru")

import re
def preprocess_txt(line):
    line = re.sub(r'\.|\"|\,', ' ', line)
    line = re.sub('\sх\s', 'x', line)
    line = re.sub('\"', ' ', line)
    line = re.sub('\-', ' ', line)

    spls = "".join(i for i in str(line).strip() if i not in exclude).split()
    spls = [i for i in spls if not i.isdigit()]

    spls = [morpher.parse(i.lower())[0].normal_form for i in spls]
    spls = [i for i in spls if i not in sw and i != ""]

    return spls

# %% [markdown]
#  ## Задача
# Разработать рекомендательную систему для аптек. Представьте, что вы приходите на кассу, а у кассира во время формирования чека всплывает подсказка, что можно вам ещё порекомендовать.
#
# Для этого рассмотрим датасеты - преобразуем соответствующие колонки, удалим пропуски и прочее
#
# Сначала рассмотрим датасет со списоком типов продуктов. Предположим, что первый элемент массива это идентификатора клиента.

# %%
with open('./data/Product_dict.pkl', 'rb') as f:
    dataTest = pickle.load(f)
dataTest = pd.DataFrame.from_dict(dataTest,  orient='index')

# %%
dataTest
# Out:
#                                                         0
# 168308               (197312) Пакет-майка 25см х 45см 906
# 134832  (62448) Перекись водорода р-р наружн. 3% фл.по...
# 101384  (72183) Салициловая кислота р-р спирт 2% фл 40...
# 168570                     (197309) Пакет 28см х 50см 906
# 146960       (111023) Пакет "Аптека Озерки" 28 х 35см 906
# ...                                                   ...
# 193603                            (110044169) название -1
# 193484                            (110050486) название -1
# 192459                            (110020427) название -1
# 193510                            (110047818) название -1
# 192468                            (110042981) название -1
#
# [30418 rows x 1 columns]

# %%
dataTest.isnull().values.any()
# Out:
# False

# %%
dataTest = pd.DataFrame.from_dict(dataTest)
dataTest['user_id'] = dataTest.index
dataTest['item_id'] = dataTest[[0]]
dataTest['user_id'] = dataTest['user_id'].astype(int)

dataTest = dataTest.reset_index()
dataTest = dataTest[['user_id', 'item_id']]
dataTest
# Out:
#        user_id                                            item_id
# 0       168308               (197312) Пакет-майка 25см х 45см 906
# 1       134832  (62448) Перекись водорода р-р наружн. 3% фл.по...
# 2       101384  (72183) Салициловая кислота р-р спирт 2% фл 40...
# 3       168570                     (197309) Пакет 28см х 50см 906
# 4       146960       (111023) Пакет "Аптека Озерки" 28 х 35см 906
# ...        ...                                                ...
# 30413   193603                            (110044169) название -1
# 30414   193484                            (110050486) название -1
# 30415   192459                            (110020427) название -1
# 30416   193510                            (110047818) название -1
# 30417   192468                            (110042981) название -1
#
# [30418 rows x 2 columns]

# %% [markdown]
# Как показано у описания товара есть идентификтор и само описание выделим отдельно эти две сущности. Также видим что у некторых товаров отсутствует название, в этом случае удалим такие товары. Так при если нет названия то мы не можем просто клиенту предложить такой товар

# %%
def preprocessTxt(line, filter = True):
    line = line.lower()
    lines = line.split(')')
    
    if len(lines) >= 2 and filter:
        line = lines[1].strip()
        return line
    
    if len(lines) >= 2 and not filter:
        line = lines[0].replace("(", "").strip()
        return line

dataTest['itemName'] = dataTest["item_id"].apply(preprocessTxt, args=(True,))
dataTest['itemId'] = dataTest["item_id"].apply(preprocessTxt, args=(False,))

# %%
dataTest
# Out:
#        user_id                                            item_id  \
# 0       168308               (197312) Пакет-майка 25см х 45см 906
# 1       134832  (62448) Перекись водорода р-р наружн. 3% фл.по...
# 2       101384  (72183) Салициловая кислота р-р спирт 2% фл 40...
# 3       168570                     (197309) Пакет 28см х 50см 906
# 4       146960       (111023) Пакет "Аптека Озерки" 28 х 35см 906
# ...        ...                                                ...
# 30413   193603                            (110044169) название -1
# 30414   193484                            (110050486) название -1
# 30415   192459                            (110020427) название -1
# 30416   193510                            (110047818) название -1
# 30417   192468                            (110042981) название -1
#
#                                                 itemName     itemId
# 0                            пакет-майка 25см х 45см 906     197312
# 1      перекись водорода р-р наружн. 3% фл.полимерн. ...      62448
# 2        салициловая кислота р-р спирт 2% фл 40мл n1 404      72183
# 3                                  пакет 28см х 50см 906     197309
# 4                    пакет "аптека озерки" 28 х 35см 906     111023
# ...                                                  ...        ...
# 30413                                        название -1  110044169
# 30414                                        название -1  110050486
# 30415                                        название -1  110020427
# 30416                                        название -1  110047818
# 30417                                        название -1  110042981
#
# [30418 rows x 4 columns]

# %%
dataTest = dataTest[['user_id', 'itemName', 'itemId']]
dataTest['user_id'] = dataTest['user_id'].astype(int)
dataTest['itemId'] = dataTest['itemId'].astype(str)
dataTest
# Out:
# <ipython-input-174-63e398d6b6d4>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataTest['user_id'] = dataTest['user_id'].astype(int)
# <ipython-input-174-63e398d6b6d4>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataTest['itemId'] = dataTest['itemId'].astype(str)
#        user_id                                           itemName     itemId
# 0       168308                        пакет-майка 25см х 45см 906     197312
# 1       134832  перекись водорода р-р наружн. 3% фл.полимерн. ...      62448
# 2       101384    салициловая кислота р-р спирт 2% фл 40мл n1 404      72183
# 3       168570                              пакет 28см х 50см 906     197309
# 4       146960                пакет "аптека озерки" 28 х 35см 906     111023
# ...        ...                                                ...        ...
# 30413   193603                                        название -1  110044169
# 30414   193484                                        название -1  110050486
# 30415   192459                                        название -1  110020427
# 30416   193510                                        название -1  110047818
# 30417   192468                                        название -1  110042981
#
# [30418 rows x 3 columns]

# %%
dataGood = dataTest[(dataTest['itemName'] != "название -1") ]
dataGood
# Out:
#        user_id                                           itemName  itemId
# 0       168308                        пакет-майка 25см х 45см 906  197312
# 1       134832  перекись водорода р-р наружн. 3% фл.полимерн. ...   62448
# 2       101384    салициловая кислота р-р спирт 2% фл 40мл n1 404   72183
# 3       168570                              пакет 28см х 50см 906  197309
# 4       146960                пакет "аптека озерки" 28 х 35см 906  111023
# ...        ...                                                ...     ...
# 30401   153665  очки корригирующие кемнер оптикс глянцевые пла...  121891
# 30402   164193                   лактулоза форте пор.15мл №10 597  190054
# 30403   153013  курапрокс набор (зубная паста вайт из блэк 90м...  121465
# 30404    59719  лиерак премиум набор бархат новогодний (крем 5...  117974
# 30410   103197  бельведер тушь д/ресниц антибактериальная крем...   94866
#
# [29860 rows x 3 columns]

# %%
dataGood.to_csv('./data/goods.csv', index=False)

# %%
dataGood['text'] = dataGood['itemName'].apply(lambda x: preprocess_txt(str(x)))
dataGood
# Out:
# <ipython-input-177-13d19c7dc279>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataGood['text'] = dataGood['itemName'].apply(lambda x: preprocess_txt(str(x)))
#        user_id                                           itemName  itemId  \
# 0       168308                        пакет-майка 25см х 45см 906  197312
# 1       134832  перекись водорода р-р наружн. 3% фл.полимерн. ...   62448
# 2       101384    салициловая кислота р-р спирт 2% фл 40мл n1 404   72183
# 3       168570                              пакет 28см х 50см 906  197309
# 4       146960                пакет "аптека озерки" 28 х 35см 906  111023
# ...        ...                                                ...     ...
# 30401   153665  очки корригирующие кемнер оптикс глянцевые пла...  121891
# 30402   164193                   лактулоза форте пор.15мл №10 597  190054
# 30403   153013  курапрокс набор (зубная паста вайт из блэк 90м...  121465
# 30404    59719  лиерак премиум набор бархат новогодний (крем 5...  117974
# 30410   103197  бельведер тушь д/ресниц антибактериальная крем...   94866
#
#                                                     text
# 0                               [пакет, майк, 25смx45см]
# 1      [перекись, водород, р, р, наружн, фл, полимерн...
# 2      [салициловый, кислота, р, р, спирт, фл, 40мл, n1]
# 3                                     [пакет, 28смx50см]
# 4                       [пакет, аптека, озерко, 28x35см]
# ...                                                  ...
# 30401  [очки, корригировать, кемнер, оптикс, глянцевы...
# 30402                       [лактулоза, форт, 15мл, №10]
# 30403  [курапрокс, набор, зубной, паста, вайта, блэк,...
# 30404  [лиерак, премиум, набор, бархат, новогодний, к...
# 30410  [бельведер, тушь, дресница, антибактериальный,...
#
# [29860 rows x 4 columns]

# %% [markdown]
# # Обработка датасета покупок
# Дынные датасета чековых покупок. Удалим пропуски данных  и преобразуем данные как прошлой порцией данных

# %%
checkData = pd.read_csv('./data/chackData.csv')
# Out:
# c:\study\venv\lib\site-packages\IPython\core\interactiveshell.py:3418: DtypeWarning: Columns (1) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
checkData.dropna(inplace=True)
checkData
# Out:
#          sale_date_date contact_id  shop_id  product_id  \
# 0            2018-12-07    1260627   1455.0    168308.0
# 1            2018-12-07     198287    279.0    134832.0
# 2            2018-12-07    2418385    848.0    101384.0
# 3            2018-12-07    1285774   1511.0    168570.0
# 4            2018-12-07    1810323   1501.0    168319.0
# ...                 ...        ...      ...         ...
# 19999995     2018-06-13    1601618   1499.0     66842.0
# 19999996     2018-06-13    1394104   1495.0    136795.0
# 19999997     2018-06-13    1570654   1516.0    119513.0
# 19999998     2018-06-13    1924036   1485.0     71723.0
# 19999999     2018-06-13    1788779   1503.0     66164.0
#
#                                                        name  \
# 0                          (197312) Пакет-майка 25см х 45см
# 1         (62448) Перекись водорода р-р наружн. 3% фл.по...
# 2         (72183) Салициловая кислота р-р спирт 2% фл 40...
# 3                                (197309) Пакет 28см х 50см
# 4                                (197310) Пакет 30см х 60см
# ...                                                     ...
# 19999995  (111992) Кэа Хэлс Ромашка [цветки фильтр-пакет...
# 19999996        (97857) Лориста Н таб. п.о. 50мг+12.5мг №90
# 19999997                     (25299) Локрен тб п/о 20мг N28
# 19999998           (60907) Тералиджен табл. п.п.о. 5 мг №25
# 19999999                  (27922) Дифлюкан капс. 150 мг. №1
#
#           product_sub_category_id  product_category_id  brand_id quantity
# 0                           906.0                205.0      -1.0     1,00
# 1                           404.0                 93.0      -1.0     1,00
# 2                           404.0                 93.0      -1.0     1,00
# 3                           906.0                205.0      -1.0     1,00
# 4                           906.0                205.0      -1.0     1,00
# ...                           ...                  ...       ...      ...
# 19999995                    615.0                140.0    1838.0     1,00
# 19999996                    738.0                170.0      -1.0     1,00
# 19999997                    738.0                170.0      -1.0     1,00
# 19999998                    637.0                146.0      -1.0     1,00
# 19999999                    622.0                142.0      -1.0     1,00
#
# [19989262 rows x 9 columns]

# %%
checkData['itemName'] = checkData["name"].apply(preprocessTxt, args=(True,))
checkData['itemId'] = checkData["name"].apply(preprocessTxt, args=(False,))

# %%
checkData['Data'] = pd.to_datetime(checkData['sale_date_date'], format='%Y-%m-%d')
checkData.rename({'contact_id': 'user_id'}, axis=1, inplace=True)
checkData
# Out:
#          sale_date_date  user_id  shop_id  product_id  \
# 0            2018-12-07  1260627   1455.0    168308.0
# 1            2018-12-07   198287    279.0    134832.0
# 2            2018-12-07  2418385    848.0    101384.0
# 3            2018-12-07  1285774   1511.0    168570.0
# 4            2018-12-07  1810323   1501.0    168319.0
# ...                 ...      ...      ...         ...
# 19999995     2018-06-13  1601618   1499.0     66842.0
# 19999996     2018-06-13  1394104   1495.0    136795.0
# 19999997     2018-06-13  1570654   1516.0    119513.0
# 19999998     2018-06-13  1924036   1485.0     71723.0
# 19999999     2018-06-13  1788779   1503.0     66164.0
#
#                                                        name  \
# 0                          (197312) Пакет-майка 25см х 45см
# 1         (62448) Перекись водорода р-р наружн. 3% фл.по...
# 2         (72183) Салициловая кислота р-р спирт 2% фл 40...
# 3                                (197309) Пакет 28см х 50см
# 4                                (197310) Пакет 30см х 60см
# ...                                                     ...
# 19999995  (111992) Кэа Хэлс Ромашка [цветки фильтр-пакет...
# 19999996        (97857) Лориста Н таб. п.о. 50мг+12.5мг №90
# 19999997                     (25299) Локрен тб п/о 20мг N28
# 19999998           (60907) Тералиджен табл. п.п.о. 5 мг №25
# 19999999                  (27922) Дифлюкан капс. 150 мг. №1
#
#           product_sub_category_id  product_category_id  brand_id quantity  \
# 0                           906.0                205.0      -1.0     1,00
# 1                           404.0                 93.0      -1.0     1,00
# 2                           404.0                 93.0      -1.0     1,00
# 3                           906.0                205.0      -1.0     1,00
# 4                           906.0                205.0      -1.0     1,00
# ...                           ...                  ...       ...      ...
# 19999995                    615.0                140.0    1838.0     1,00
# 19999996                    738.0                170.0      -1.0     1,00
# 19999997                    738.0                170.0      -1.0     1,00
# 19999998                    637.0                146.0      -1.0     1,00
# 19999999                    622.0                142.0      -1.0     1,00
#
#                                                    itemName  itemId       Data
# 0                                   пакет-майка 25см х 45см  197312 2018-12-07
# 1         перекись водорода р-р наружн. 3% фл.полимерн. ...   62448 2018-12-07
# 2               салициловая кислота р-р спирт 2% фл 40мл n1   72183 2018-12-07
# 3                                         пакет 28см х 50см  197309 2018-12-07
# 4                                         пакет 30см х 60см  197310 2018-12-07
# ...                                                     ...     ...        ...
# 19999995     кэа хэлс ромашка [цветки фильтр-пакеты 1г] n20  111992 2018-06-13
# 19999996                лориста н таб. п.о. 50мг+12.5мг №90   97857 2018-06-13
# 19999997                             локрен тб п/о 20мг n28   25299 2018-06-13
# 19999998                   тералиджен табл. п.п.о. 5 мг №25   60907 2018-06-13
# 19999999                          дифлюкан капс. 150 мг. №1   27922 2018-06-13
#
# [19989262 rows x 12 columns]

# %%
dataTransform = checkData[['Data','user_id','product_id', 'itemId','itemName', 'quantity']].copy()
dataTransform.reset_index()
dataTransform
# Out:
#                Data  user_id  product_id  itemId  \
# 0        2018-12-07  1260627    168308.0  197312
# 1        2018-12-07   198287    134832.0   62448
# 2        2018-12-07  2418385    101384.0   72183
# 3        2018-12-07  1285774    168570.0  197309
# 4        2018-12-07  1810323    168319.0  197310
# ...             ...      ...         ...     ...
# 19999995 2018-06-13  1601618     66842.0  111992
# 19999996 2018-06-13  1394104    136795.0   97857
# 19999997 2018-06-13  1570654    119513.0   25299
# 19999998 2018-06-13  1924036     71723.0   60907
# 19999999 2018-06-13  1788779     66164.0   27922
#
#                                                    itemName quantity
# 0                                   пакет-майка 25см х 45см     1,00
# 1         перекись водорода р-р наружн. 3% фл.полимерн. ...     1,00
# 2               салициловая кислота р-р спирт 2% фл 40мл n1     1,00
# 3                                         пакет 28см х 50см     1,00
# 4                                         пакет 30см х 60см     1,00
# ...                                                     ...      ...
# 19999995     кэа хэлс ромашка [цветки фильтр-пакеты 1г] n20     1,00
# 19999996                лориста н таб. п.о. 50мг+12.5мг №90     1,00
# 19999997                             локрен тб п/о 20мг n28     1,00
# 19999998                   тералиджен табл. п.п.о. 5 мг №25     1,00
# 19999999                          дифлюкан капс. 150 мг. №1     1,00
#
# [19989262 rows x 6 columns]

# %%
dataTransform['user_id'] = dataTransform['user_id'].astype(int)
dataTransform['product_id'] = dataTransform['product_id'].astype(int)
dataTransform['quantity'] = dataTransform['quantity'].astype(str).str.replace(',', '.').astype(float)

dataTransform['quantity'] = dataTransform.apply(lambda row: 1 if (row["quantity"] > 0) else 0, axis=1)
dataTransform
# Out:
#                Data  user_id  product_id  itemId  \
# 0        2018-12-07  1260627      168308  197312
# 1        2018-12-07   198287      134832   62448
# 2        2018-12-07  2418385      101384   72183
# 3        2018-12-07  1285774      168570  197309
# 4        2018-12-07  1810323      168319  197310
# ...             ...      ...         ...     ...
# 19999995 2018-06-13  1601618       66842  111992
# 19999996 2018-06-13  1394104      136795   97857
# 19999997 2018-06-13  1570654      119513   25299
# 19999998 2018-06-13  1924036       71723   60907
# 19999999 2018-06-13  1788779       66164   27922
#
#                                                    itemName  quantity
# 0                                   пакет-майка 25см х 45см         1
# 1         перекись водорода р-р наружн. 3% фл.полимерн. ...         1
# 2               салициловая кислота р-р спирт 2% фл 40мл n1         1
# 3                                         пакет 28см х 50см         1
# 4                                         пакет 30см х 60см         1
# ...                                                     ...       ...
# 19999995     кэа хэлс ромашка [цветки фильтр-пакеты 1г] n20         1
# 19999996                лориста н таб. п.о. 50мг+12.5мг №90         1
# 19999997                             локрен тб п/о 20мг n28         1
# 19999998                   тералиджен табл. п.п.о. 5 мг №25         1
# 19999999                          дифлюкан капс. 150 мг. №1         1
#
# [19989262 rows x 6 columns]

# %%
dataTransform.to_csv('./data/checkBuy.csv', index=False)

# %%
dataTransform.head(5)
# Out:
#         Data  user_id  product_id  itemId  \
# 0 2018-12-07  1260627      168308  197312
# 1 2018-12-07   198287      134832   62448
# 2 2018-12-07  2418385      101384   72183
# 3 2018-12-07  1285774      168570  197309
# 4 2018-12-07  1810323      168319  197310
#
#                                             itemName  quantity
# 0                            пакет-майка 25см х 45см         1
# 1  перекись водорода р-р наружн. 3% фл.полимерн. ...         1
# 2        салициловая кислота р-р спирт 2% фл 40мл n1         1
# 3                                  пакет 28см х 50см         1
# 4                                  пакет 30см х 60см         1

# %%
dataTransform[dataTransform['user_id'] == 2520366]
# Out:
#               Data  user_id  product_id  itemId  \
# 2337288 2018-11-21  2520366      158549  181234
# 2337799 2018-11-21  2520366      158586  181229
# 2338402 2018-11-21  2520366      158600  181232
# 2387394 2018-11-21  2520366      162832  185573
# 2485383 2018-11-21  2520366       22832   57208
# 2485933 2018-11-21  2520366       22470  114118
# 2487993 2018-11-21  2520366       51228  107758
#
#                                         itemName  quantity
# 2337288  pl шприц одноразовый инсулиновый 1мл №1         1
# 2337799      pl шприц одноразовый 3-комп. 2мл №1         1
# 2338402      pl шприц одноразовый 3-комп. 5мл №1         1
# 2387394                  минки ватные диски №100         1
# 2485383                   пакет нд "майка" 28х50         1
# 2485933    pl вода питьевая негазированная 500мл         1
# 2487993         pl аскорбинка с сахаром таб. №10         1

# %% [markdown]
# Валидационный датасет. Разумнее всего сделать его из датасета checkData, по последней дате покупки для каждого пользователя. Выберем по последней дате

# %%
validateData = dataTransform.sort_values(by=['Data','user_id'] ,ascending=True ).drop_duplicates(['user_id'], keep="last")[[ "Data" , "user_id", "itemId"]]
validateData
# validateData.to_csv('./data/validatdataTransformeData.csv', index=False)
# Out:
#               Data  user_id  itemId
# 4743900 2018-01-01      399   61227
# 4744412 2018-01-01    12207   51910
# 4744392 2018-01-01    17512   65438
# 4743837 2018-01-01    20239   55073
# 6685757 2018-01-01    22182   58542
# ...            ...      ...     ...
# 115256  2018-12-09  2742143  120201
# 115342  2018-12-09  2743330  184313
# 235812  2018-12-09  2746142   89316
# 115269  2018-12-09  2746260  109962
# 115322  2018-12-09  2746261   27847
#
# [1642125 rows x 3 columns]

# %% [markdown]
# удалим товары ндс - как ненужный элемент

# %%
dataTransform = dataTransform[(dataTransform['itemId'] != '48791') ]
dataTransform.reset_index()
dataTransform
# Out:
#                Data  user_id  product_id  itemId  \
# 0        2018-12-07  1260627      168308  197312
# 1        2018-12-07   198287      134832   62448
# 2        2018-12-07  2418385      101384   72183
# 3        2018-12-07  1285774      168570  197309
# 4        2018-12-07  1810323      168319  197310
# ...             ...      ...         ...     ...
# 19999995 2018-06-13  1601618       66842  111992
# 19999996 2018-06-13  1394104      136795   97857
# 19999997 2018-06-13  1570654      119513   25299
# 19999998 2018-06-13  1924036       71723   60907
# 19999999 2018-06-13  1788779       66164   27922
#
#                                                    itemName  quantity
# 0                                   пакет-майка 25см х 45см         1
# 1         перекись водорода р-р наружн. 3% фл.полимерн. ...         1
# 2               салициловая кислота р-р спирт 2% фл 40мл n1         1
# 3                                         пакет 28см х 50см         1
# 4                                         пакет 30см х 60см         1
# ...                                                     ...       ...
# 19999995     кэа хэлс ромашка [цветки фильтр-пакеты 1г] n20         1
# 19999996                лориста н таб. п.о. 50мг+12.5мг №90         1
# 19999997                             локрен тб п/о 20мг n28         1
# 19999998                   тералиджен табл. п.п.о. 5 мг №25         1
# 19999999                          дифлюкан капс. 150 мг. №1         1
#
# [19820071 rows x 6 columns]

# %% [markdown]
# После проверки оказалось, что клиенты редко когда повторяються в течении всего промежутка времени. Обычно для одного клиента есть одна покупка - больше информации нет, тем более мы можем прикрутить к системе рекомендации еще один кандидатогенератор, который будет рандомно предлагать товары из ранее купленных.
#
# Можно предложить валидационный датасет, тогда когда система будет работать в боевом режиме  И у нас будет информация что из предложенного клиент купил. А в настоящей время простой повтор ранее купленных товаров будет работать лучше, чем сложные алгоритмы
#
# Но в целях изучения я реализую для них все методы

# %% [markdown]
#  # Факторизационные машины
#  В настоящей релизации нужна огромный массив - показывает ошибку
#  Unstacked DataFrame is too big, causing int32 overflow
#  Поэтому реализацию таким методом мы отпустим

# %%
# shell = pd.pivot_table(
#     dataTransform, 
#     index="user_id", 
#     columns="product_id", 
#     values="quantity"
# )
# shell.head()

# %% [markdown]
# # Колаборативннная фильтрация
#
# данные метод применяется для рекоммендательной системе имеющих данные рейтинга
# Данная система хороша для оценки фильмы/музыки так как прослушаешь ты ее один раз. Лекарства имеют свойства заканчиваться поэтому проще предлагать те ассоритметы , которые уже  клиентом покупались!
#
# Можно ввести бинарный признак покупки/непокупки однако для оценки нужно пройстись по всем товарам - а это порядка 36000 асортиментов Это долго - можно оценить купит он продукт или не купит по топу продаваемых товаров
# Но у нас такого топа нет
#
# Поэтому реализуем три кандидатагенератора
#  1. По близким названиям - FastTest
#  2. По ранее купленным таварам клиента
#  3. по 1000 самым продаваемым товарам
#  4. Предложим пакет обязательно!

# %% [markdown]
#  1000 самых покумаемых товаров

# %%
dataTransform = dataTransform[['user_id', 'itemId', 'itemName']]
dataTransform
# Out:
#           user_id  itemId                                           itemName
# 0         1260627  197312                            пакет-майка 25см х 45см
# 1          198287   62448  перекись водорода р-р наружн. 3% фл.полимерн. ...
# 2         2418385   72183        салициловая кислота р-р спирт 2% фл 40мл n1
# 3         1285774  197309                                  пакет 28см х 50см
# 4         1810323  197310                                  пакет 30см х 60см
# ...           ...     ...                                                ...
# 19999995  1601618  111992     кэа хэлс ромашка [цветки фильтр-пакеты 1г] n20
# 19999996  1394104   97857                лориста н таб. п.о. 50мг+12.5мг №90
# 19999997  1570654   25299                             локрен тб п/о 20мг n28
# 19999998  1924036   60907                   тералиджен табл. п.п.о. 5 мг №25
# 19999999  1788779   27922                          дифлюкан капс. 150 мг. №1
#
# [19820071 rows x 3 columns]

# %%
# popular = analisData['itemId'].value_counts()
popular = dataTransform['itemId'].value_counts().rename_axis('itemId').reset_index(name='counts')

# %%
mostPopular = popular.iloc[:1000]
mostPopular
# Out:
#      itemId  counts
# 0    197312  118106
# 1    181542   89851
# 2     57733   87792
# 3    117825   77153
# 4     81509   73543
# ..      ...     ...
# 995   37757    4416
# 996   28587    4415
# 997   79902    4403
# 998   45406    4402
# 999   55610    4400
#
# [1000 rows x 2 columns]

# %%
# mostPopular.to_csv('./data/mostPopular.csv', index=False)
# dataTransform.to_csv('./data/dataTransform.csv', index=False)

# %%
import random as rnd

mostPopularItem = list(mostPopular['itemId'].values)
users = list(dataTransform['user_id'].values)

usersMostPopular = pd.DataFrame()
for user in users:
    userPopular = dataTransform[(dataTransform['user_id'] == user) &
                                (dataTransform['itemId'].isin(mostPopularItem))]


    if not userPopular.empty:
        userPopular['Buy'] = 1
        usersMostPopular = pd.concat([usersMostPopular, userPopular], ignore_index=True, axis=0).copy()
    else:
        number = rnd.randrange(0, len(mostPopularItem) - 1)
        itemId = mostPopularItem[number]
        itemName = dataTransform[dataTransform['itemId'] == itemId].iloc[0]['itemName']
        userNotBy = {"user_id": [user],
                     'itemId': [mostPopularItem[number]],
                     'itemName': [itemName],
                     'Buy': [0]}
        userPopular = pd.DataFrame.from_dict(userNotBy)
        usersMostPopular = pd.concat([usersMostPopular, userPopular], ignore_index=True, axis=0).copy()
# Out:
# <ipython-input-233-3fbb952a556e>:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   userPopular['Buy'] = 1
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# <ipython-input-233-3fbb952a556e> in <module>
#       6 usersMostPopular = pd.DataFrame()
#       7 for user in users:
# ----> 8     userPopular = dataTransform[(dataTransform['user_id'] == user) &
#       9                                 (dataTransform['itemId'].isin(mostPopularItem))]
#      10
#
# c:\study\venv\lib\site-packages\pandas\core\ops\common.py in new_method(self, other)
#      67         other = item_from_zerodim(other)
#      68
# ---> 69         return method(self, other)
#      70
#      71     return new_method
#
# c:\study\venv\lib\site-packages\pandas\core\arraylike.py in __and__(self, other)
#      60     @unpack_zerodim_and_defer("__and__")
#      61     def __and__(self, other):
# ---> 62         return self._logical_method(other, operator.and_)
#      63
#      64     @unpack_zerodim_and_defer("__rand__")
#
# c:\study\venv\lib\site-packages\pandas\core\series.py in _logical_method(self, other, op)
#    5511         rvalues = extract_array(other, extract_numpy=True, extract_range=True)
#    5512
# -> 5513         res_values = ops.logical_op(lvalues, rvalues, op)
#    5514         return self._construct_result(res_values, name=res_name)
#    5515
#
# c:\study\venv\lib\site-packages\pandas\core\ops\array_ops.py in logical_op(left, right, op)
#     390         filler = fill_int if is_self_int_dtype and is_other_int_dtype else fill_bool
#     391
# --> 392         res_values = na_logical_op(lvalues, rvalues, op)
#     393         # error: Cannot call function of unknown type
#     394         res_values = filler(res_values)  # type: ignore[operator]
#
# c:\study\venv\lib\site-packages\pandas\core\ops\array_ops.py in na_logical_op(x, y, op)
#     300         # Then Cases where this goes through without raising include:
#     301         #  (xint or xbool) and (yint or bool)
# --> 302         result = op(x, y)
#     303     except TypeError:
#     304         if isinstance(y, np.ndarray):
#
# MemoryError: Unable to allocate 18.9 MiB for an array with shape (19820071,) and data type bool

# %%
# usersMostPopular.to_csv('./data/usersMostPopular.csv', index=False)
usersMostPopular = pd.read_csv('./data/usersMostPopular.csv')
usersMostPopular
# Out:
#         user_id     itemId                                     itemName  Buy
# 0       1260627     197312                      пакет-майка 25см х 45см    1
# 1       1260627     197309                            пакет 28см х 50см    1
# 2       1260627  110048492                                     название    1
# 3       1260627      35743            шприцы одноразовые с иглой 5мл n1    1
# 4       1260627      13804   л-тироксин 50 берлин хеми табл. 50 мкг №50    1
# ...         ...        ...                                          ...  ...
# 922705  1069360      60747                      вестибо таб. 24 мг. №30    1
# 922706  1069360      98434      тромбо асс тб п/о кишечнораств 50мг n28    1
# 922707  1069360      60747                      вестибо таб. 24 мг. №30    1
# 922708  1069360      41942                           эгилок тб 50мг n60    1
# 922709  1069360     118115  предуктал од капс.пролонг.действия 80мг №30    1
#
# [922710 rows x 4 columns]

# %%
usersMostPopular.rename({'itemName': 'title','user_id': 'userId', 'Buy': 'rating', }, axis=1, inplace=True)
usersMostPopular = usersMostPopular[['title', 'userId', 'rating']]
usersMostPopular.head(5)
# Out:
#                                         title   userId  rating
# 0                     пакет-майка 25см х 45см  1260627       1
# 1                           пакет 28см х 50см  1260627       1
# 2                                    название  1260627       1
# 3           шприцы одноразовые с иглой 5мл n1  1260627       1
# 4  л-тироксин 50 берлин хеми табл. 50 мкг №50  1260627       1

# %%
from surprise import KNNWithMeans, KNNBasic
from surprise import Dataset
from surprise import accuracy
from surprise import Reader
from surprise.model_selection import train_test_split

# %%
reader = Reader(rating_scale=(0.0, 1.0))
data = Dataset.load_from_df(usersMostPopular, reader)

# %%
trainset, testset = train_test_split(data, test_size=0.15)

algo = KNNWithMeans(k=50, sim_options={'name': 'pearson_baseline', 'user_based': True})
algo.fit(trainset)

test_pred = algo.test(testset)
# Out:
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.

# %%
accuracy.rmse(test_pred, verbose=True)
# Out:
# RMSE: 0.0384
# 0.0384341480939196

# %%
import pickle

def saveModel(filname = "", model = None):
    pickle.dump(model, open(filname, 'wb'))
    
def readModel(filname = ""):
    loaded_model = pickle.load(open(filname, 'rb'))    
    return loaded_model

# %%
filenameColab = './model/modelColad.txt'
saveModel(filname = filenameColab, model = algo)

# %% [markdown]
# Как видно результат не очень хороший - много пользователей и много наименвоаний товаров
#
# Но все равно реализуем в качестве учебы функцию выбора купленного бы товара

# %%
titlePopular = list(usersMostPopular['title'].values)
usersMostPopular
# Out:
#                                               title   userId  rating
# 0                           пакет-майка 25см х 45см  1260627       1
# 1                                 пакет 28см х 50см  1260627       1
# 2                                          название  1260627       1
# 3                 шприцы одноразовые с иглой 5мл n1  1260627       1
# 4        л-тироксин 50 берлин хеми табл. 50 мкг №50  1260627       1
# ...                                             ...      ...     ...
# 922705                      вестибо таб. 24 мг. №30  1069360       1
# 922706      тромбо асс тб п/о кишечнораств 50мг n28  1069360       1
# 922707                      вестибо таб. 24 мг. №30  1069360       1
# 922708                           эгилок тб 50мг n60  1069360       1
# 922709  предуктал од капс.пролонг.действия 80мг №30  1069360       1
#
# [922710 rows x 3 columns]

# %%
import random as rnd
filenameColab = './model/modelColad.txt'
modelcolab = readModel(filname = filenameColab)
def generatorUser(userID = None):
    collect = []
    titleSelect = rnd.choice(titlePopular)
    titleProb = modelcolab.predict(uid=userID, iid=titleSelect).est
    while len(collect) < 3:        
        titleSelect = rnd.choice(titlePopular)
        titleProb = modelcolab.predict(uid=userID, iid=titleSelect).est
        if titleProb >= 0.995:
            collect.append(titleSelect)
    return collect

# %%
generatorUser(userID =1260627 )
# Out:
# ['ортофен тб п/о 25мг n20',
#  'глюкофаж таб.п.п.о.500мг №60',
#  'лекролин капли глазн 20мг/мл фл-капел 10мл n1']

# %% [markdown]
# ## Построены рекомендации с Word2Vec
# Псотроим модель Word2Vec и

# %%
dataTransform
# Out:
#           user_id  itemId                                           itemName
# 0         1260627  197312                            пакет-майка 25см х 45см
# 1          198287   62448  перекись водорода р-р наружн. 3% фл.полимерн. ...
# 2         2418385   72183        салициловая кислота р-р спирт 2% фл 40мл n1
# 3         1285774  197309                                  пакет 28см х 50см
# 4         1810323  197310                                  пакет 30см х 60см
# ...           ...     ...                                                ...
# 19999995  1601618  111992     кэа хэлс ромашка [цветки фильтр-пакеты 1г] n20
# 19999996  1394104   97857                лориста н таб. п.о. 50мг+12.5мг №90
# 19999997  1570654   25299                             локрен тб п/о 20мг n28
# 19999998  1924036   60907                   тералиджен табл. п.п.о. 5 мг №25
# 19999999  1788779   27922                          дифлюкан капс. 150 мг. №1
#
# [19820071 rows x 3 columns]

# %%
dataTransform['text'] = dataTransform['itemName'].apply(lambda x: preprocess_txt(str(x)))
# Out:
# <ipython-input-35-727f2b1d69f0>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataTransform['text'] = dataTransform['itemName'].apply(lambda x: preprocess_txt(str(x)))

# %%
from gensim.models import FastText
from gensim.models import Word2Vec

# %%
sentences = [i for i in dataTransform['text'] if len(i) > 2]
modelFT = FastText(sentences=sentences, vector_size=20, min_count=1, window=5)
modelWV = Word2Vec(sentences=sentences, vector_size=20, min_count=1, window=5)

# %%
# modelFT.save("./model/modelFT")
# modelWV.save("./model/modelWV")

# %%
modelWV = Word2Vec.load('./model/modelWV')
dataTransform.head(5)
# Out:
#    user_id  itemId                                           itemName  \
# 0  1260627  197312                            пакет-майка 25см х 45см
# 1   198287   62448  перекись водорода р-р наружн. 3% фл.полимерн. ...
# 2  2418385   72183        салициловая кислота р-р спирт 2% фл 40мл n1
# 3  1285774  197309                                  пакет 28см х 50см
# 4  1810323  197310                                  пакет 30см х 60см
#
#                                                 text
# 0                           [пакет, майк, 25смx45см]
# 1  [перекись, водород, р, р, наружн, фл, полимерн...
# 2  [салициловый, кислота, р, р, спирт, фл, 40мл, n1]
# 3                                 [пакет, 28смx50см]
# 4                                 [пакет, 30смx60см]

# %%
modelWV = Word2Vec.load('./model/modelWV')
indexProduct = annoy.AnnoyIndex(20 ,'angular')

index_product = {}
index_itemId = {}
counter = 0

for index, row in dataTransform.iterrows():
    n_w2v = 0
    itemName = row['itemName']
    itemId = row['itemId']
    
    index_product[counter] = itemName
    index_itemId[counter] = itemId

    text = row['text']

    vector = np.zeros(20)
    for word in text:
        if word in modelWV.wv:
            vector += modelWV.wv[word]
            n_w2v += 1
    if n_w2v > 0:
        vector = vector / n_w2v
    indexProduct.add_item(counter, vector)
    counter += 1
    
indexProduct.build(10)
indexProduct.save('./model/similarProduct.ann')
# Out:
# True

# %%
index_product
# Out:
# {0: 'пакет-майка 25см х 45см',
#  1: 'перекись водорода р-р наружн. 3% фл.полимерн. 100мл',
#  2: 'салициловая кислота р-р спирт 2% фл 40мл n1',
#  3: 'пакет 28см х 50см',
#  4: 'пакет 30см х 60см',
#  5: 'кеппра таб.п.п.о.500мг №30',
#  6: 'пакет 28см х 50см',
#  7: 'пакет-майка 25см х 45см',
#  8: 'перекись водорода р-р наружн. 3% фл.полимерн. 100мл',
#  9: 'пакет-майка 25см х 45см',
#  10: 'пакет "аптека озерки" 28 х 35см',
#  11: 'пакет 28см х 50см',
#  12: 'карта забота о здоровье',
#  13: 'пакет-майка 25см х 45см',
#  14: 'пакет-майка 25см х 45см',
#  15: 'пакет "аптека озерки" 28 х 35см',
#  16: 'пакет-майка 25см х 45см',
#  17: 'ранитидин тб 150мг уп n20',
#  18: 'пакет-майка 25см х 45см',
#  19: 'платки носовые "зева кидс" №10',
#  20: 'пакет майка "благодарим за покупку" (28+14',
#  21: 'иглы микро-файн д/шприц-ручки 30g 0,3*8мм n100',
#  22: 'пакет майка "благодарим за покупку" (28+14',
#  23: 'дорзопт капли глазные 2% 5мл. фл.-кап. n3',
#  24: 'пакет 28см х 50см',
#  25: 'pl шприц одноразовый 3-комп. 3мл №1',
#  26: 'pl шприц одноразовый 3-комп. 5мл №1',
#  27: 'аллапинин тб 25мг n30',
#  28: 'корвалол капли д/приема внутрь 25мл',
#  29: 'азафен тб 25мг №50',
#  30: 'pl контейнер д/биопроб универс. 120мл полим. с крыш. в инд. уп.',
#  31: 'pl контейнер д/биопроб стер. 60мл с крыш и ложкой в инд.уп',
#  32: 'метотрексат-эбеве р-р д/и 10мг/мл шприц 1,5мл №1',
#  33: 'pl шприц одноразовый 3-комп. 3мл №1',
#  34: 'pl салфетка антисептическая спиртовая 3х6см №1',
#  35: 'pl вода питьевая негазированная 330мл',
#  36: 'калия перманганат пор фл 5г n1',
#  37: 'регидрон пор дозир пак 18.9г n20',
#  38: 'pl шприц одноразовый 3-комп. 5мл №1',
#  39: 'pl шприц одноразовый 3-комп. 10мл №1',
#  40: 'микстура от кашля для детей сухая пор д/оралн р-ра 1.47г пак n1',
#  41: 'микстура от кашля для детей сухая пор д/оралн р-ра 1.47г пак n1',
#  42: 'азитрал капс 500мг n3',
#  43: 'pl шприц одноразовый 3-комп. 5мл №1',
#  44: 'pl аскорбиновая кислота с глюкозой тб 100мг №10',
#  45: 'сульфацил натрия капли глазн 20% тюб-капел 1.5мл n2',
#  46: 'флуконазол капс. 150мг №2',
#  47: 'горчичник пакет n20',
#  48: 'pl шприц одноразовый 3-комп. 20мл №1',
#  49: 'повязка cosmopor e на рану самоклеящаяся стерильная 5 х 7,2см (900870/901008',
#  50: 'трусопт капли глазн 2% 5мл фл n1',
#  51: 'винпоцетин таб.5мг №50',
#  52: 'глюкованс табл. п.о. 500 мг/5 мг №30',
#  53: 'нафтизин р-р 0.1% фл/кап 20мл n1',
#  54: 'линекс форте капс. №14',
#  55: 'смекта апельсин пор. 3 гр. n10',
#  56: 'аевит капс n10',
#  57: 'фемостон 2 (2/10',
#  58: 'цитрамон п таб.№10',
#  59: 'pl хлоргексидин биглюконат р-р 0.05% фл.100мл №1 (ндс 18%',
#  60: 'минки ватные палочки №100 стакан',
#  61: 'эвкалипта настойка жидк фл 25мл n1',
#  62: 'аскорбиновая кислота  драже 50мг n200',
#  63: 'фраксипарин р-р для п/к введ.5700ме шприц 0,6мл №10',
#  64: 'pl салфетка антисептическая спиртовая 3х6см №1',
#  65: 'цитрамон п таб.№10',
#  66: 'калия перманганат пор фл 5г n1',
#  67: 'повязка cosmopor e на рану самоклеящаяся стерильная 5 х 7,2см (900870/901008',
#  68: 'тромбо асс тб п/о кишечнораств 50мг n100',
#  69: 'магний-диаспорал 300 гран.д/пригот.р-ра д/приема внутрь 300мг №50 пакет',
#  70: 'корвалол капли д/приема внутрь 25мл',
#  71: 'меновазин раствор д/наружн. применен. спиртовой фл. 40мл',
#  72: 'верошпирон таб.25мг №20',
#  73: 'pl аскорбиновая кислота с глюкозой тб 100мг №10',
#  74: 'дюфалак сироп 667мг/мл фл.500мл',
#  75: 'pl салфетка антисептическая спиртовая 13,5х18,5см №1',
#  76: 'шприц одноразовый sf medical 3-комп.2мл №1/стм',
#  77: 'pl аскорбинка порошок пак.2,5г №1',
#  78: 'дексаметазон р-р д/ин. 4 мг/мл. амп. 1 мл. №25',
#  79: 'энтеросгель паста д/приема внутрь туба 225 гр.',
#  80: 'ацетилсалициловая кислота таб.500мг №20',
#  81: 'pl салфетка антисептическая спиртовая 3х6см №1',
#  82: 'нафтизин р-р 0.1% фл/кап 20мл n1',
#  83: 'риностоп капли наз. 0,1% фл. 10мл',
#  84: 'фосфалюгель гель 16г n20',
#  85: 'кэа хэлс сенна [листья фильтр-пакеты 1.5г] n20',
#  86: 'календулы настойка жидк фл 40мл n1',
#  87: 'сенаде тб 13.5мг n500',
#  88: 'pl кальция глюконат таб.500мг №10',
#  89: 'дьюралан 60мг шприц 3мл уп.№1',
#  90: 'крем "нега" массажный туба 75мл n1',
#  91: 'дона р-р для в/м введения 400мг амп 2мл №6',
#  92: 'пульмикорт сусп д/инг 0,5мг/мл контейнер 2мл n20',
#  93: 'pl хлоргексидин биглюконат р-р 0.05% фл.100мл №1 (ндс 18%',
#  94: 'слабилен капли 0.75% 15мл фл n1',
#  95: 'тауфон капли глазн 4% фл 10 мл. пласт. флак.-кап.',
#  96: 'pl шприц одноразовый 3-комп. 5мл №1',
#  97: 'пульмикорт сусп д/инг 0,25мг/мл контейнер 2мл n20',
#  98: 'pl аскорбинка с сахаром таб. клубника №10',
#  99: 'ямми карамель леденцовая с витамином с вишня 17г',
#  100: 'прополиса настойка жидк.фл.25мл №1',
#  101: 'pl бальзам для губ фруктовый микс 4,2г',
#  102: 'ябудужить100лет гематоген спортивный 40г',
#  103: 'pl шприц одноразовый 3-комп. 5мл №1',
#  104: 'ит ми фрутилад батончик черника 30г',
#  105: 'ит ми фрутилад батончик апельсин-брусника 30г',
#  106: 'ябудужить100лет гематоген спортивный 40г',
#  107: 'глаупрост капли глазные 0,005% фл.-кап. 2,5мл №3',
#  108: 'глаупрост капли глазные 0,005% фл.-кап. 2,5мл №3',
#  109: 'диафлекс ромфарм капс. 50мг №30',
#  110: 'гроссхертц кальций д3 таб.№30',
#  111: 'минки платочки бумажные носовые №10',
#  112: 'ябудужить100лет гематоген спортивный 40г',
#  113: 'ябудужить100лет гематоген спортивный 40г',
#  114: 'виш формула летучая мышь маска-лифтинг маска для контура глаз 8мл',
#  115: 'ябудужить100лет гематоген спортивный 40г',
#  116: 'неокейт lcp смесь сухая для питания детей раннего возраста 400г',
#  117: 'ябудужить100лет гематоген спортивный 40г',
#  118: 'мукалтин тб 50мг n10',
#  119: 'терафлю от гриппа и простуды пор.д/приг.р-ра д/приема внутрь лимон №10',
#  120: 'зубная нить "oral-b" essential floss мята 50м уп №1',
#  121: 'ябудужить100лет гематоген спортивный 40г',
#  122: 'ябудужить100лет гематоген спортивный 40г',
#  123: 'румалон р-р для в/м введ. 1мл №25',
#  124: 'шприц одноразовый sf medical 3-комп.2мл №1/стм',
#  125: 'шприцы "bd emerald" 5мл с иглой 0,7х30мм 3-х комп. №100',
#  126: 'ябудужить100лет гематоген спортивный 40г',
#  127: 'нью лайф бинт марл мед стер 7м х 14см уп n1/стм',
#  128: 'ябудужить100лет гематоген спортивный 40г',
#  129: 'минки платочки бумажные носовые №10',
#  130: 'минки платочки бумажные носовые №10',
#  131: 'ябудужить100лет гематоген спортивный 40г',
#  132: 'триган-д таб.№100',
#  133: 'ябудужить100лет гематоген спортивный 40г',
#  134: 'кеналог 40 сусп. д/ин. 40 мг/мл. амп. 1 мл. №5',
#  135: 'зизу платочки бумажные носовые №10',
#  136: 'минки платочки бумажные носовые №10',
#  137: 'ябудужить100лет гематоген спортивный 40г',
#  138: 'платки носовые "зева делюкс ромашка" №10',
#  139: 'ямми турбогематоген детский 30г',
#  140: 'ябудужить100лет гематоген спортивный 40г',
#  141: 'цитрамон п таб.№10',
#  142: 'корвалол капли д/приема внутрь 25мл',
#  143: 'фурацилин тб 20мг n10',
#  144: 'ябудужить100лет гематоген спортивный 40г',
#  145: 'перчатки "peha-soft vinyl" виниловые н/стерил.без пудры р-р s №2',
#  146: 'повязка cosmopor e на рану самоклеящаяся стерильная 6 х 10см (900871/901009',
#  147: 'нимесил гран.д/приг.суспен.д/приема внутрь 100мг пак.2г №30',
#  148: 'гроссхертц гинкго билоба капс.№30',
#  149: 'корвалол капли д/приема внутрь 25мл',
#  150: 'пустырник настойка фл.25мл',
#  151: 'pl салфетка антисептическая спиртовая 3х6см №1',
#  152: 'ябудужить100лет гематоген спортивный 40г',
#  153: 'глаупрост капли глазные 0,005% фл.-кап. 2,5мл №3',
#  154: 'глаупрост капли глазные 0,005% фл.-кап. 2,5мл №3',
#  155: 'зизу платочки бумажные носовые №10',
#  156: 'ябудужить100лет гематоген спортивный 40г',
#  157: 'ябудужить100лет гематоген спортивный 40г',
#  158: 'ябудужить100лет л-карнитин и таурин пор. №10 саше',
#  159: 'пиона настойка жидк фл 25мл n1',
#  160: 'боярышник [настойка фл 25мл] n1',
#  161: 'ябудужить100лет гематоген спортивный 40г',
#  162: 'ябудужить100лет гематоген спортивный 40г',
#  163: 'ябудужить100лет гематоген спортивный 40г',
#  164: 'pl шприц одноразовый 3-комп. 3мл №1',
#  165: 'престариум а тб 5мг №30',
#  166: 'ябудужить100лет гематоген спортивный 40г',
#  167: 'фурадонин авексима таб.50мг №10',
#  168: 'амоксиклав таб.п.п.о.875мг+125мг №14',
#  169: 'цитрамон п таб.№20 renewal',
#  170: 'ябудужить100лет гематоген спортивный 40г',
#  171: 'ябудужить100лет гематоген спортивный 40г',
#  172: 'ябудужить100лет гематоген спортивный 40г',
#  173: 'ябудужить100лет гематоген спортивный 40г',
#  174: 'pl гематоген 25г',
#  175: 'ямми турбогематоген детский 30г',
#  176: 'триган-д таб.№100',
#  177: 'минеральная вода зайечицкая горькая 0,5л.',
#  178: 'флуконазол капс. 150мг №2',
#  179: 'зизу салфетки влажные антибактериальные №10',
#  180: 'ябудужить100лет гематоген спортивный 40г',
#  181: 'стики пластырь бактерицидный невидимый 2,5х5,6см №10',
#  182: 'пульмикорт сусп д/инг 0,5мг/мл контейнер 2мл n20',
#  183: 'парацетамол таб.500мг №10',
#  184: 'ибупрофен табл.п.о. 200мг n50',
#  185: 'pl комплекс расторопша-овес капс.№30',
#  186: 'ябудужить100лет гематоген спортивный 40г',
#  187: 'ацетилсалициловая кислота таб.500мг №20',
#  188: 'ябудужить100лет гематоген спортивный 40г',
#  189: 'pl шприц одноразовый 3-комп. 5мл №1',
#  190: 'ямми турбогематоген детский 30г',
#  191: 'pl шприц одноразовый 3-комп. 3мл №1',
#  192: 'уголь активированный тб 250мг n10',
#  193: 'немозол таб.п.п.о.400мг №1',
#  194: 'фестал драже n100',
#  195: 'парацетамол таб.500мг №10',
#  196: 'pl шприц одноразовый 3-комп. 2мл №1',
#  197: 'натрия тетраборат (бура',
#  198: 'пульмикорт сусп д/инг 0,5мг/мл контейнер 2мл n20',
#  199: 'пипетка медицинская глазная в футляре шт n1',
#  200: 'максиколд рино апельсин пор.д/приг.р-ра д/приема внутрь пак.15г №10',
#  201: 'аскофен-п таб.№10',
#  202: 'максиколд рино апельсин пор.д/приг.р-ра д/приема внутрь пак.15г №10',
#  203: 'pl шприц одноразовый инсулиновый 1мл №1',
#  204: 'фудо йод батончик функциональный 25г',
#  205: 'фудо железо батончик функциональный 25г',
#  206: 'ямми карамель леденцовая с витамином с клубника 17г',
#  207: 'терафлю от гриппа и простуды экстра пор.д/приг.р-ра д/приема внутрь лимон №10',
#  208: 'терафлю от гриппа и простуды пор.д/приг.р-ра д/приема внутрь лесные ягоды №10',
#  209: 'жанин др №21 х 3',
#  210: 'соска пустышка латексная "ягодка" n1',
#  211: 'pl бинт марл мед н/стер 7м х 14см уп №1',
#  212: 'ярина плюс табл. п.п.о №28*3',
#  213: 'минки платочки бумажные носовые №10',
#  214: 'нимесил гран.д/приг.суспен.д/приема внутрь 100мг пак.2г №30',
#  215: 'парацетамол таб.0,5г №20',
#  216: 'максиколд рино лимон пор.д/приг.р-ра д/приема внутрь пак.15г №10',
#  217: 'риностоп капли наз. 0,1% фл. 10мл',
#  218: 'ямми кисель черника с витаминами 25г',
#  219: 'pl рыбий жир микс вкусов для детей капс.№120',
#  220: 'лейкопластырь унипласт бактерицидный влагостойкий 2,5 х 7,2см n1',
#  221: 'pl перчатки латексные нестерильные неопудренные р.m 50 пар',
#  222: 'микстура от кашля для взрослых сухая пор д/оралн р-ра 1.7г пак n1',
#  223: 'pl вода питьевая негазированная 500мл',
#  224: 'нафтизин р-р 0.05% тюб.-кап 20мл №1',
#  225: 'немозол таб.п.п.о.400мг №1',
#  226: 'новаринг кольцо вагинальное №3',
#  227: 'доксициклин капс 100мг n10',
#  228: 'феррогематоген плитка 50г уп n1',
#  229: 'диоксидин р-р д/и 0,5% амп 10мл n10',
#  230: 'индол форте капс. 230 мг №30',
#  231: 'найз гран.для приг.сусп.д/приема внутрь 100мг пак.№9',
#  232: 'pl шприц одноразовый 3-комп. 3мл №1',
#  233: 'кетанов р-р д/и 30мг амп 1мл n10',
#  234: 'цефтриаксон пор.д/р-ра в/в, в/м фл. 1г',
#  235: 'pl шприц одноразовый 3-комп. 5мл №1',
#  236: 'pl салфетка антисептическая спиртовая 3х6см №1',
#  237: 'pl шприц одноразовый 3-комп. 2мл №1',
#  238: 'pl шприц одноразовый 3-комп. 5мл №1',
#  239: 'феррогематоген плитка 50г уп n1',
#  240: 'корвалол капли д/приема внутрь 25мл',
#  241: 'pl контейнер д/биопроб универс. 120мл полим. с крыш. в инд. уп.',
#  242: 'натрия хлорид 0.9% р-р д/инфуз фл 200мл №1',
#  243: 'йода р-р спирт 5% фл 10мл n1',
#  244: 'борная кислота р-р спирт 3% фл 25мл n1',
#  245: 'нимесил гран.д/приг.суспен.д/приема внутрь 100мг пак.2г №30',
#  246: 'терафлю от гриппа и простуды пор.д/приг.р-ра д/приема внутрь лесные ягоды №10',
#  247: 'pl салфетка антисептическая спиртовая 3х6см №1',
#  248: 'pl маска медицинская №3',
#  249: 'pl шприц одноразовый 3-комп. 3мл №1',
#  250: 'pl шприц одноразовый 3-комп. 2мл №1',
#  251: 'шприц одноразовый sf medical 3-комп.2мл №1/стм',
#  252: 'маалокс сусп.д/приема внутрь пак.15мл №30',
#  253: 'нимесил гран.д/приг.суспен.д/приема внутрь 100мг пак.2г №30',
#  254: 'фестал драже n100',
#  255: 'аскорбиновая кислота с глюкозой тб 100мг n10',
#  256: 'фанни банни помада гигиеническая от ветра и непогоды д/детей 4 г',
#  257: 'тизин эксперт/ксило био спрей наз.доз.фл.с доз.0,1% 10мл №1',
#  258: 'сенаде тб 13.5мг n500',
#  259: 'корвалол капли д/приема внутрь 25мл',
#  260: 'ангидак спрей д/местного прим.0,255мг/доза 176 доз фл.30мл',
#  261: 'pl хлоргексидин биглюконат р-р 0.05% фл.100мл №1 (ндс 18%',
#  262: 'pl бинт марл мед стер гост 5м х 10см уп №1',
#  263: 'pl салфетка антисептическая спиртовая 13,5х18,5см №1',
#  264: 'перекись водорода р-р наружн. 3% фл.полимерн. 100мл',
#  265: 'нью лайф бинт марл мед н/стер 7м х 14см инд.уп/стм',
#  266: 'pl бинт марл мед стер 5м х 10см уп №1',
#  267: 'метилурациловая мазь 10% 25г n1',
#  268: 'pl салфетка антисептическая спиртовая 3х6см №1',
#  269: 'pl шприц одноразовый 3-комп. 5мл №1',
#  270: 'дицинон таб.250мг №100',
#  271: 'фосфалюгель гель 16г n20',
#  272: 'магний-диаспорал 300 гран.д/пригот.р-ра д/приема внутрь 300мг №50 пакет',
#  273: 'диоксидин р-р д/и 0,5% амп 10мл n10',
#  274: 'сенаде тб 13.5мг n500',
#  275: 'элевит пронаталь таб.п.п.о.№100',
#  276: 'pl шприц одноразовый 3-комп. 2мл №1',
#  277: 'корвалол капли д/приема внутрь 25мл',
#  278: 'пластырь перцовый 10см х 18см уп n1',
#  279: 'регидрон пор дозир пак 18.9г n20',
#  280: 'pl салфетка антисептическая спиртовая 13,5х18,5см №1',
#  281: 'микстура от кашля для детей сухая пор д/оралн р-ра 1.47г пак n1',
#  282: 'pl салфетка антисептическая спиртовая 3х6см №1',
#  283: 'изопринозин тб 500мг n50',
#  284: 'аскорбиновая кислота с глюкозой тб 100мг n10',
#  285: 'лазолван рино спрей назальный 10мл',
#  286: 'pl шприц одноразовый 3-комп. 2мл №1',
#  287: 'pl салфетка антисептическая спиртовая 3х6см №1',
#  288: 'ацетилсалициловая кислота таб.500мг №20',
#  289: 'нолипрел а таб.п.п.о.2,5мг+0,625мг №30',
#  290: 'ригевидон табл. п.о. №63',
#  291: 'повязка cosmopor e на рану самоклеящаяся стерильная 5 х 7,2см (900870/901008',
#  292: 'повязка cosmopor e на рану самоклеящаяся стерильная 8 х 10см (900873/901020',
#  293: 'регидрон пор дозир пак 18.9г n20',
#  294: 'pl салфетка антисептическая спиртовая 3х6см №1',
#  295: 'pl шприц одноразовый 3-комп. 5мл №1',
#  296: 'новинет табл. п.п.о. №63',
#  297: 'повязка cosmopor antibacterial самокл. серебросодержащ. (drybarrier',
#  298: 'корвалол капли д/приема внутрь 25мл',
#  299: 'силденафил-сз таб.п.п.о. 100мг №14',
#  300: 'супрастин таб.25мг №40',
#  301: 'ацц пор.д/р-ра для приема внутрь 200мг пак.3г №20 апельсин',
#  302: 'нимесил гран.д/приг.суспен.д/приема внутрь 100мг пак.2г №30',
#  303: 'pl шприц одноразовый 3-комп. 5мл №1',
#  304: 'ацикловир-акрихин тб 200мг n20',
#  305: 'пульмикорт сусп д/инг 0,25мг/мл контейнер 2мл n20',
#  306: 'эвиталия комплекс сухих микроорганизмов пробиотиков лиоф. 300мг фл. №10',
#  307: 'pl аскорбинка с сахаром таб. №10',
#  308: 'фестал драже n100',
#  309: 'феррогематоген плитка 50г уп n1',
#  310: 'мастер юни пластырь перцовый 10х18см',
#  311: 'pl аскорбинка порошок пак.2,5г №1',
#  312: 'аквадетрим вит д3 р-р водный 15000ме/мл фл 10 мл №1',
#  313: 'цитрамон п таб.№10',
#  314: 'борная кислота пор 10г уп n1 (ндс 18%',
#  315: 'ринонорм-тева спрей наз.0,1% фл.20мл. с доз.-распыл.',
#  316: 'pl шприц одноразовый 3-комп. 3мл №1',
#  317: 'валериана [настойка фл 25мл] n1',
#  318: 'химотрипсин пор 10мг фл n10',
#  319: 'лейкопластырь бактерицидный 2.3см х 7.2см уп n1',
#  320: 'тетрациклина гидрохлорид тб п/о 100мг n20',
#  321: 'pl шприц одноразовый инсулиновый 1мл №1',
#  322: 'pl салфетка антисептическая спиртовая 13,5х18,5см №1',
#  323: 'pl шприц одноразовый 3-комп. 5мл №1',
#  324: 'хилак форте капли д/приема внутрь фл.-кап.100мл №2+1/промо',
#  325: 'pl контейнер д/биопроб универс. 120мл полим. с крыш. в инд. уп.',
#  326: 'pl контейнер д/биопроб стер. 60мл с крыш и ложкой в инд.уп',
#  327: 'троксевазин гель 2% туба 40г n1',
#  328: 'регидрон пор дозир пак 18.9г n20',
#  329: 'аторвастатин таб.п.п.о.20мг №30',
#  330: 'нью лайф бинт марл мед стер 7м х 14см уп n1/стм',
#  331: 'мята перечная н-ка фл 25мл n1',
#  332: 'максиколд рино лимон пор.д/приг.р-ра д/приема внутрь пак.15г №10',
#  333: 'мята перечная н-ка фл 25мл n1',
#  334: 'мочеприемник детский 100мл стер. n1',
#  335: 'pl контейнер д/биопроб универс. 120мл полим. с крыш. в инд. уп.',
#  336: 'бисакодил хемофарм табл. п.о. 5 мг. №30',
#  337: 'триган-д таб.№100',
#  338: 'флуконазол капс 150 мг. №1',
#  339: 'флуконазол капс 150 мг. №1',
#  340: 'мастер юни пластырь перцовый 10х18см',
#  341: 'повязка cosmopor e на рану самоклеящаяся стерильная 6 х 10см (900871/901009',
#  342: 'pl хлоргексидин биглюконат р-р 0.05% фл.100мл №1 (ндс 18%',
#  343: 'стрептоцид пор 2г пак n1',
#  344: 'максиколд рино апельсин пор.д/приг.р-ра д/приема внутрь пак.15г №10',
#  345: 'pl бахилы медицинские пара (инд.уп.',
#  346: 'повязка cosmopor e на рану самоклеящаяся стерильная 8 х 15см (900874/901021',
#  347: 'натрия хлорид 0.9% р-р д/инфуз фл 200мл №1',
#  348: 'pl шприц одноразовый 3-комп. 20мл №1',
#  349: 'преднизол р-р в/в, в/м 30мг/мл амп. 1мл №3',
#  350: 'pl шприц одноразовый 3-комп. 10мл №1',
#  351: 'преднизол р-р в/в, в/м 30мг/мл амп. 1мл №3',
#  352: 'риностоп капли наз. 0,1% фл. 10мл',
#  353: 'повязка cosmopor e на рану самоклеящаяся стерильная 10 х 20см (900876/901022',
#  354: 'мочеприемник детский 100мл стер. n1',
#  355: 'бинт эласт "peha-haft" когезивный 10см х 4м',
#  356: 'солкосерил гель 10% туба 20 гр.',
#  357: 'повязка cosmopor e на рану самоклеящаяся стерильная 6 х 10см (900871/901009',
#  358: 'pl шприц одноразовый 3-комп. 10мл №1',
#  359: 'дексаметазон р-р д/ин. 4 мг/мл. амп. 1 мл. №25',
#  360: 'мукалтин тб 50мг n20',
#  361: 'шприц одноразовый sf medical 3-комп.2мл №1/стм',
#  362: 'пакет-контейнер гипотермический (водно-солевой',
#  363: 'нимесил гран.д/приг.суспен.д/приема внутрь 100мг пак.2г №30',
#  364: 'донат магний вода минеральная 1,0л бут №1',
#  365: 'сенаде тб 13.5мг n500',
#  366: 'терафлю от гриппа и простуды экстра пор.д/приг.р-ра д/приема внутрь лимон №10',
#  367: 'pl аскорбинка порошок пак.2,5г №1',
#  368: 'вигантол р-р масл 0,5мг/мл фл-капел 10мл n1',
#  369: 'пакет-контейнер гипотермический (водно-солевой',
#  370: 'немулекс гран.д/сусп.д/приема внутрь 100мг 2г №10 пак.',
#  371: 'фталазол тб 500мг n10',
#  372: 'pl салфетка антисептическая спиртовая 3х6см №1',
#  373: 'pl шприц одноразовый 3-комп. 5мл №1',
#  374: 'феррогематоген плитка 50г уп n1',
#  375: 'микстура от кашля для детей сухая пор д/оралн р-ра 1.47г пак n1',
#  376: 'регидрон пор дозир пак 18.9г n20',
#  377: 'крем детский легкий увлажняющий 75мл',
#  378: 'дицинон таб.250мг №100',
#  379: 'pl кальция глюконат таб.500мг №10',
#  380: 'салициловая кислота р-р спирт 1% фл 40мл n1',
#  381: 'pl пипетка глазная травмобезопасная стеклянная №10',
#  382: 'нимесил гран.д/приг.суспен.д/приема внутрь 100мг пак.2г №30',
#  383: 'юнификс пластырь фиксирующий на тканевой основе 3х500см',
#  384: 'новинет табл. п.п.о. №63',
#  385: 'дицинон таб.250мг №100',
#  386: 'регулон табл. п.п.о. №63',
#  387: 'нимесил гран.д/приг.суспен.д/приема внутрь 100мг пак.2г №30',
#  388: 'бальзам золотая звезда мазь д/наружн.прим.4г №1',
#  389: 'pl бахилы медицинские пара (инд.уп.',
#  390: 'pl аскорбинка порошок пак.2,5г №1',
#  391: 'парацетамол таб.500мг №10',
#  392: 'шприц одноразовый sf medical 3-комп.5мл №1/стм',
#  393: 'анальгин таб.500мг №10',
#  394: 'энтеросгель паста д/приема внутрь туба 225 гр.',
#  395: 'нимесил гран.д/приг.суспен.д/приема внутрь 100мг пак.2г №30',
#  396: 'повязка cosmopor e на рану самоклеящаяся стерильная 6 х 10см (900871/901009',
#  397: 'кармолис леденцы без сахара 75г уп №1',
#  398: 'ямми карамель леденцовая с витамином с клубника 17г',
#  399: 'кеторолак таб. п.о. 10мг №20',
#  400: 'фурацилин тб 20мг n10',
#  401: 'касторовое масло фл 30г n1',
#  402: 'pl салфетка антисептическая спиртовая 3х6см №1',
#  403: 'стрептоцид пор 2г пак n1',
#  404: 'актовегин р-р д/ин. 40 мг/мл. амп. 2 мл. №25',
#  405: 'нью лайф салфетка марл мед стер двухслойн 29см х 45см №5/стм',
#  406: 'офломелид мазь наружн.туба 50г',
#  407: 'pl перчатки нитриловые нестерильные неопудренные р.s 100 пар цветные',
#  408: 'нормофлорин-d фл 100мл',
#  409: 'pl вода питьевая негазированная 1500мл',
#  410: 'пульмикорт сусп д/инг 0,25мг/мл контейнер 2мл n20',
#  411: 'pl аскорбинка порошок пак.2,5г №1',
#  412: 'спазган таб.№100 блистер',
#  413: 'хумалог р-р д/ин картридж 100ме/мл 3мл №5',
#  414: 'pl гематоген с кокосом 40г',
#  415: 'нимесил гран.д/приг.суспен.д/приема внутрь 100мг пак.2г №30',
#  416: 'нафтизин р-р 0.1% фл/кап 20мл n1',
#  417: 'трилакт фл 12мл',
#  418: 'pl перчатки латексные нестерильные неопудренные р.l 50 пар',
#  419: 'шприцы одноразовые с иглой 2мл уп n1',
#  420: 'аевит капс n10',
#  421: 'pl хлоргексидин биглюконат р-р 0.05% фл.100мл №1 (ндс 18%',
#  422: 'pl шприц одноразовый 3-комп. 3мл №1',
#  423: 'немозол таб.п.п.о.400мг №1',
#  424: 'микстура от кашля для взрослых сухая пор д/оралн р-ра 1.7г пак n1',
#  425: 'pl хлоргексидин биглюконат р-р 0.05% фл.100мл №1 (ндс 18%',
#  426: 'вигантол р-р масл 0,5мг/мл фл-капел 10мл n1',
#  427: 'pl бинт марл мед н/стер гост 7м х 14см уп №1',
#  428: 'pl бинт марл мед стер гост 5м х 10см уп №1',
#  429: 'тизин классик/ксило спрей наз. 0,1% фл. 10мл',
#  430: 'нимесил гран.д/приг.суспен.д/приема внутрь 100мг пак.2г №30',
#  431: 'триган-д таб.№100',
#  432: 'регидрон пор дозир пак 18.9г n20',
#  433: 'pl пипетка глазная травмобезопасная стеклянная №10',
#  434: 'нимесил гран.д/приг.суспен.д/приема внутрь 100мг пак.2г №30',
#  435: 'галазолин капли 0.1% 10мл n1',
#  436: 'pl бахилы медицинские пара (инд.уп.',
#  437: 'pl салфетка антисептическая спиртовая 3х6см №1',
#  438: 'тетрациклиновая  мазь глазн 10000ед/г туба 3г n1',
#  439: 'дексаметазон р-р д/ин. 4 мг/мл. амп. 1 мл. №25',
#  440: 'коэнзим композитум 2,2мл амп №100',
#  441: 'мастер юни пластырь перцовый 10х18см',
#  442: 'pl шприц одноразовый 3-комп. 3мл №1',
#  443: 'повязка cosmopor e на рану самоклеящаяся стерильная 8 х 15см (900874/901021',
#  444: 'пектусин таб.д/рассас.№10',
#  445: 'натрия хлорид 0.9% р-р д/инфуз фл 200мл n28',
#  446: 'маалокс сусп.д/приема внутрь пак.15мл №30',
#  447: 'pl аскорбиновая кислота с глюкозой тб 100мг №10',
#  448: 'минеральная вода билинска киселка 1л',
#  449: 'дексаметазон р-р д/ин. 4 мг/мл. амп. 1 мл. №25',
#  450: 'тантум роза р-р вагинальный 0.1% фл.-спринц.140мл с канюлей №5',
#  451: 'карипазим 350 пе фл №1',
#  452: 'меновазин раствор д/наружн. применен. спиртовой фл. 40мл',
#  453: 'нимесил гран.д/приг.суспен.д/приема внутрь 100мг пак.2г №30',
#  454: 'ямми мармелад микс 50г',
#  455: 'триган-д таб.№100',
#  456: 'цель т р-р д/и амп 2,2мл №100',
#  457: 'pl салфетка антисептическая спиртовая 3х6см №1',
#  458: 'ябудужить100лет гематоген спортивный 40г',
#  459: 'сенаде тб 13.5мг n500',
#  460: 'pl салфетка антисептическая спиртовая 3х6см №1',
#  461: 'левомеколь мазь 40г n1',
#  462: 'pl шприц одноразовый 3-комп. 2мл №1',
#  463: 'микстура от кашля для детей сухая пор д/оралн р-ра 1.47г пак n1',
#  464: 'pl шприц одноразовый 3-комп. 3мл №1',
#  465: 'лоперамид таб.2мг №20',
#  466: 'ямми карамель леденцовая с витамином с малина-ежевика 17г',
#  467: 'pl хлоргексидин биглюконат р-р 0.05% фл.100мл №1 (ндс 18%',
#  468: 'pl салфетка антисептическая спиртовая 3х6см №1',
#  469: 'тизин классик/ксило спрей наз. 0,1% фл. 10мл',
#  470: 'презерватив "viva" для узи №1',
#  471: 'бифидум баг 1000доз фл.12мл №1',
#  472: 'цитрамон п таб.№10',
#  473: 'pl шприц одноразовый 3-комп. 5мл №1',
#  474: 'нимесил гран.д/приг.суспен.д/приема внутрь 100мг пак.2г №30',
#  475: 'pl шприц одноразовый инсулиновый 1мл №1',
#  476: 'pl контейнер д/биопроб универс. 120мл полим. с крыш. в инд. уп.',
#  477: 'галазолин капли 0.1% 10мл n1',
#  478: 'pl салфетка антисептическая спиртовая 3х6см №1',
#  479: 'ямми карамель леденцовая с витамином с дюшес 17г',
#  480: 'pl салфетка антисептическая спиртовая 3х6см №1',
#  481: 'норваск таб.5мг №30',
#  482: 'цефтриаксон пор.д/р-ра в/в, в/м фл./пачка 1г №50',
#  483: 'нутридринк смесь д/энтер.питания клубника 200мл',
#  484: 'сенаде тб 13.5мг n500',
#  485: 'повязка branolind n стерильная мазевая 7.5см х 10см n1 арт.492343',
#  486: 'парацетамол таб.500мг №10',
#  487: 'ромашка [цветки фильтр-пакеты 1.5г] n20 клс',
#  488: 'pl шприц одноразовый 3-комп. 10мл №1',
#  489: 'корвалол капли д/приема внутрь 25мл',
#  490: 'валидол таб.подъяз.60мг №10',
#  491: 'мастер юни пластырь перцовый 10х18см',
#  492: 'беталок зок таб.п.о.замедл.высв.25мг №14 блистер',
#  493: 'кэа хэлс ромашка [цветки фильтр-пакеты 1г] n20',
#  494: 'pl салфетка антисептическая спиртовая 13,5х18,5см №1',
#  495: 'цитрамон п таб.№10',
#  496: 'монурал гран.д/приг.р-ра.д/приема внутрь 3г саше №1',
#  497: 'pl хлоргексидин биглюконат р-р 0.05% фл.100мл №1 (ндс 18%',
#  498: 'панкреатин табл. п.о.кш.раств. №50',
#  499: 'pl шприц одноразовый 3-комп. 2мл №1',
#  500: 'pl салфетка антисептическая спиртовая 3х6см №1',
#  501: 'pl шприц одноразовый 3-комп. 2мл №1',
#  502: 'перекись водорода р-р наружн. 3% фл.полимерн. 100мл',
#  503: 'pl хлоргексидин биглюконат р-р 0.05% фл.100мл №1 (ндс 18%',
#  504: 'pl бинт марл мед н/стер 7м х 14см уп №1',
#  505: 'сенаде тб 13.5мг n500',
#  506: 'роаккутан капс 10мг n30',
#  507: 'феварин таб. п.о.100мг №15',
#  508: 'самсон&далила гематоген русский 40г с кедровым орехом',
#  509: 'pl шприц одноразовый 3-комп. 5мл №1',
#  510: 'микстура от кашля для взрослых сухая пор д/оралн р-ра 1.7г пак n1',
#  511: 'ацетилсалициловая кислота таб.500мг №10',
#  512: 'меновазин раствор д/наружн. применен. спиртовой фл. 40мл',
#  513: 'натрия хлорид 0.9% р-р д/инфуз фл 400мл n1',
#  514: 'бисопролол-тева таб. 5мг №30',
#  515: 'аевит капс n20',
#  516: 'ингавирин капс.90мг №7',
#  517: 'pl хлоргексидин биглюконат р-р 0.05% фл.100мл №1 (ндс 18%',
#  518: 'pl хлоргексидин биглюконат р-р 0.05% фл.100мл №1 (ндс 18%',
#  519: 'перчатки "peha-soft vinyl" виниловые н/стерил.без пудры р-р s №2',
#  520: 'цитрамон п таб.№10',
#  521: 'pl салфетка антисептическая спиртовая 3х6см №1',
#  522: 'самсон&далила гематоген русский 40г детский',
#  523: 'pl салфетка антисептическая спиртовая 3х6см №1',
#  524: 'йода р-р спирт 5% фл 10мл n1 с крышкой-помазком renewal',
#  525: 'аскорутин таб.№50',
#  526: 'pl аевитамин капс.№20',
#  527: 'pl аскорбинка с сахаром таб. клубника №10',
#  528: 'перекись водорода р-р наружн. 3% фл.полимерн. 100мл',
#  529: 'нимесил гран.д/приг.суспен.д/приема внутрь 100мг пак.2г №30',
#  530: 'левомицетин тб 500мг n10',
#  531: 'донат магний вода минеральная 1,0л бут №1',
#  532: 'pl шприц одноразовый 3-комп. 2мл №1',
#  533: 'pl шприц одноразовый инсулиновый 1мл №1',
#  534: 'pl шприц одноразовый 3-комп. 2мл №1',
#  535: 'pl шприц одноразовый 3-комп. 2мл №1',
#  536: 'pl шприц одноразовый 3-комп. 5мл №1',
#  537: 'pl салфетка антисептическая спиртовая 3х6см №1',
#  538: 'витатека пластырь перцовый перфорированный 10х18см №1',
#  539: 'натрия хлорид 0.9% р-р д/инфуз бут 250мл №10',
#  540: 'pl шприц одноразовый 3-комп. 3мл №1',
#  541: 'перекись водорода р-р наружн. 3% фл.полимерн. 100мл',
#  542: 'клексан р-р д/инъекций 20мг 0,2мл шпр. №10',
#  543: 'микстура от кашля для детей сухая пор д/оралн р-ра 1.47г пак n1',
#  544: 'фенибут тб 0.25г n10',
#  545: 'нафтизин р-р 0.1% фл/кап 20мл n1',
#  546: 'феррогематоген плитка 50г уп n1',
#  547: 'лейкопластырь мозольный "салипод" 2см х10см',
#  548: 'римантадин таб.50мг №20',
#  549: 'пустырник настойка фл.25мл',
#  550: 'pl рыбий жир с витаминами а, д, е капс. №100',
#  551: 'pl шприц одноразовый 3-комп. 2мл №1',
#  552: 'мукоза композитум р-р для в/м и п/к введ.гомеоп.2,2мл амп.№100',
#  553: 'дексаметазон р-р д/ин. 4 мг/мл. амп. 1 мл. №25',
#  554: 'pl салфетка антисептическая спиртовая 3х6см №1',
#  555: 'pl кальция глюконат таб.500мг №10',
#  556: 'pl перчатки нитриловые нестерильные неопудренные р.m 100 пар цветные',
#  557: 'pl салфетка антисептическая спиртовая 3х6см №1',
#  558: 'камфорный спирт р-р 2% фл 40мл',
#  559: 'pl аскорбинка с сахаром таб. №10',
#  560: 'pl аскорбинка порошок пак.2,5г №1',
#  561: 'фенибут тб 0.25г n10',
#  562: 'pl шприц одноразовый инсулиновый 1мл №1',
#  563: 'pl кальция глюконат таб.500мг №10',
#  564: 'микстура от кашля для взрослых сухая пор д/оралн р-ра 1.7г пак n1',
#  565: 'натрия хлорид 0.9% р-р д/инфуз фл 200мл №1',
#  566: 'нормофлорин-d фл 100мл',
#  567: 'pl перчатки латексные нестерильные неопудренные р.l 50 пар',
#  568: 'pl вода питьевая негазированная 1500мл',
#  569: 'фамвиталь капс.№90',
#  570: 'валериана [настойка фл 25мл] n1',
#  571: 'pl кальция глюконат таб.500мг №10',
#  572: 'pl салфетка антисептическая спиртовая 3х6см №1',
#  573: 'pl салфетка антисептическая спиртовая 3х6см №1',
#  574: 'самсон&далила гематоген русский 40г детский',
#  575: 'пульмикорт сусп д/инг 0,5мг/мл контейнер 2мл n20',
#  576: 'нафтизин р-р 0.1% фл/кап 20мл n1',
#  577: 'pl шприц одноразовый 3-комп. 5мл №1',
#  578: 'pl шприц одноразовый 3-комп. 5мл №1',
#  579: 'цитрамон п таб.№10',
#  580: 'салфетки "soft-zellin" спиртовые для инъекций 60мм х 30мм №100',
#  581: 'салфетки "soft-zellin" спиртовые для инъекций 60мм х 30мм №100',
#  582: 'норваск таб.5мг №30',
#  583: 'энтеросгель паста д/приема внутрь туба 225 гр.',
#  584: 'регидрон пор дозир пак 18.9г n20',
#  585: 'триган-д таб.№100',
#  586: 'pl салфетка антисептическая спиртовая 3х6см №1',
#  587: 'натрия хлорид 0.9% р-р д/инфуз фл 400мл n1',
#  588: 'фенибут тб 0.25г n10',
#  589: 'pl шприц одноразовый 3-комп. 5мл №1',
#  590: 'pl хлоргексидин биглюконат р-р 0.05% фл.100мл №1 (ндс 18%',
#  591: 'pl бинт марл мед н/стер гост 7м х 14см уп №1',
#  592: 'система трансфуз д/переливания крови, кровезам, инфуз р-ров уп n1',
#  593: 'pl шприц одноразовый 3-комп. 2мл №1',
#  594: 'липоевая кислота тб п/о 25 мг. №50',
#  595: 'календулы настойка жидк фл 40мл n1',
#  596: 'pl шприц одноразовый 3-комп. 5мл №1',
#  597: 'уголь активированный тб 250мг n10',
#  598: 'шприц одноразовый sf medical 3-комп.2мл №1/стм',
#  599: 'pl аевитамин капс.№20',
#  600: 'pl контейнер д/биопроб стер. 60мл с крыш и ложкой в инд.уп',
#  601: 'pl хлоргексидин биглюконат р-р 0.05% фл.100мл №1 (ндс 18%',
#  602: 'корвалол капли д/приема внутрь 25мл',
#  603: 'коэнзим композитум 2,2мл амп №100',
#  604: 'микстура от кашля для взрослых сухая пор д/оралн р-ра 1.7г пак n1',
#  605: 'микстура от кашля для детей сухая пор д/оралн р-ра 1.47г пак n1',
#  606: 'пакет 30см х 60см',
#  607: 'глиатилин капс 400мг n14',
#  608: 'гордокс р-р д/ин. 100000 кие/10 мл. амп. 10 мл. №25',
#  609: 'цефтриаксон пор д/приг. р-ра д/в/в, в/м введ 1г фл n50',
#  610: 'валериана [экстракт тб п/об 20мг] n50',
#  611: 'флуконазол капс 150 мг. №1',
#  612: 'pl шприц одноразовый инсулиновый 1мл №1',
#  613: 'валидол табл. сублингв. 0,06 гр. №10',
#  614: 'флуконазол капс 150 мг. №1',
#  615: 'ямми турбогематоген детский 30г',
#  616: 'салициловая мазь 2% 25г n1',
#  617: 'бификол сухой пор  5дз n10',
#  618: 'pl шприц одноразовый 3-комп. 2мл №1',
#  619: 'мукалтин тб 50мг n10',
#  620: 'мастер юни пластырь перцовый 10х18см',
#  621: 'феррогематоген плитка 50г уп n1',
#  622: 'перекись водорода р-р наружн. 3% фл.полимерн. 100мл',
#  623: 'цитрамон п таб.№10',
#  624: 'нормофлорин-d фл 100мл',
#  625: 'pl хлоргексидин биглюконат р-р 0.05% фл.100мл №1 (ндс 18%',
#  626: 'эмла крем д/местного и наружн.прим.5% туба 5г №5',
#  627: 'pl шприц одноразовый 3-комп. 2мл №1',
#  628: 'диклофенак гель д/наружн.прим.5% 30г',
#  629: 'pl шприц одноразовый 3-комп. 5мл №1',
#  630: 'феррогематоген плитка 50г уп n1',
#  631: 'самсон&далила гематоген русский 40г детский',
#  632: 'pl салфетка антисептическая спиртовая 3х6см №1',
#  633: 'pl шприц одноразовый 3-комп. 3мл №1',
#  634: 'бифидум баг 1000доз фл.12мл №1',
#  635: 'цитрамон п таб.№10',
#  636: 'pl сироп шиповника фл.250мл',
#  637: 'аркоксиа табл. п.п.о.90мг №28',
#  638: 'ямми карамель леденцовая с витамином с лимон-мята 17г',
#  639: 'pl шприц одноразовый 3-комп. 5мл №1',
#  640: 'тримедат форте таб.пролонг.п.п.о.300мг №20',
#  641: 'pl хлоргексидин биглюконат р-р 0.05% фл.100мл №1 (ндс 18%',
#  642: 'корвалол капли д/приема внутрь 25мл',
#  643: 'pl перчатки нитриловые нестерильные неопудренные р.s 100 пар цветные',
#  644: 'сенаде тб 13.5мг n500',
#  645: 'перекись водорода р-р наружн. 3% фл.полимерн. 100мл',
#  646: 'натрия хлорид 0.9% р-р д/инфуз фл 500мл №10',
#  647: 'бонвива 0,15 гр. №1',
#  648: 'повязка branolind стерильная мазевая 10см х 20см №1',
#  649: 'стрептоцид пор 2г пак n1',
#  650: 'pl шприц одноразовый 3-комп. 2мл №1',
#  651: 'pl шприц одноразовый 3-комп. 5мл №1',
#  652: 'pl контейнер д/биопроб универс. 120мл полим. с крыш. в инд. уп.',
#  653: 'напальчник медицинский №1',
#  654: 'pl шприц одноразовый 3-комп. 5мл №1',
#  655: 'pl салфетка антисептическая спиртовая 3х6см №1',
#  656: 'pl салфетка антисептическая спиртовая 3х6см №1',
#  657: 'pl шприц одноразовый 3-комп. 2мл №1',
#  658: 'pl шприц одноразовый 3-комп. 5мл №1',
#  659: 'pl шприц одноразовый инсулиновый 1мл №1',
#  660: 'pl алоэ вера гель питьевой с соком черники 100г',
#  661: 'pl шприц одноразовый 3-комп. 2мл №1',
#  662: 'pl шприц одноразовый 3-комп. 5мл №1',
#  663: 'цитрамон п таб.№10',
#  664: 'бициллин-5 пор д/и 1500000ед фл n1',
#  665: 'биовестин-лакто раствор 12мл №1',
#  666: 'натрия хлорид 0.9% р-р д/инфуз фл 200мл №1',
#  667: 'бициллин-5 пор д/и 1500000ед фл n1',
#  668: 'pl шприц одноразовый 3-комп. 5мл №1',
#  669: 'оксолиновая мазь 0.25% 10г n1',
#  670: 'pl пластырь бактерицидный влагостойкий воздухопроницаемый 1,9х7,2см №1',
#  671: 'биовестин-лакто раствор 12мл №1',
#  672: 'шприц бектон дикинсон одноразовый с иглой 2-комп.10мл уп n1',
#  673: 'pl салфетка антисептическая спиртовая 3х6см №1',
#  674: 'маалокс сусп.д/приема внутрь пак.15мл №30',
#  675: 'нафтизин р-р 0.1% фл/кап 20мл n1',
#  676: 'pl рыбий жир с витаминами а, д, е капс. №100',
#  677: 'pl салфетка антисептическая спиртовая 13,5х18,5см №1',
#  678: 'дипроспан сусп.д/и амп 1мл n1',
#  679: 'pl вода питьевая негазированная спортивная 500мл',
#  680: 'неосмектин пор. д/сусп. пак. 3 гр. №30',
#  681: 'pl салфетка антисептическая спиртовая 3х6см №1',
#  682: 'мексидол р-р д/в/в и в/м введ. 50мг/мл амп. 5мл №5',
#  683: 'pl шприц одноразовый 3-комп. 2мл №1',
#  684: 'pl шприц одноразовый 3-комп. 5мл №1',
#  685: 'pl хлоргексидин биглюконат р-р 0.05% фл.100мл №1 (ндс 18%',
#  686: 'нафтизин плюс капли назальные 0.1% 15мл n1',
#  687: 'pl шприц одноразовый 3-комп. 20мл №1',
#  688: 'корвалол капли д/приема внутрь 25мл',
#  689: 'pl салфетка антисептическая спиртовая 3х6см №1',
#  690: 'цитрамон п таб.№10',
#  691: 'pl шприц одноразовый 3-комп. 2мл №1',
#  692: 'pl гематоген 25г',
#  693: 'ацетилсалициловая кислота таб.500мг №10',
#  694: 'pl шприц одноразовый 3-комп. 5мл №1',
#  695: 'сульфокамфокаин р-р д/и 10% амп 2мл n10',
#  696: 'pl шприц одноразовый инсулиновый 1мл №1',
#  697: 'pl аскорбиновая кислота с глюкозой тб 100мг №10',
#  698: 'нафтизин р-р 0.1% фл/кап 20мл n1',
#  699: 'триган-д таб.№100',
#  700: 'мукалтин тб 50мг n10',
#  701: 'нафтизин р-р 0.1% фл/кап 20мл n1',
#  702: 'pl шприц одноразовый инсулиновый 1мл №1',
#  703: 'минеральная вода винцентка 0,7л',
#  704: 'pl валериана+хмель+мята драже №30',
#  705: 'pl контейнер д/биопроб универс. 120мл полим. с крыш. в инд. уп.',
#  706: 'pl аскорбиновая кислота с глюкозой тб 100мг №10',
#  707: 'нафтизин р-р 0.1% фл/кап 20мл n1',
#  708: 'pl шприц одноразовый 3-комп. 2мл №1',
#  709: 'цитрамон п таб.№10',
#  710: 'pl гематоген детский с курагой 40г',
#  711: 'pl маска медицинская №1 инд.упак.',
#  712: 'мастер юни пластырь перцовый 10х18см',
#  713: 'афобазол таб.10мг №60',
#  714: 'аскофен-п таб.№10',
#  715: 'pl бинт марл мед стер гост 5м х 10см уп №1',
#  716: 'атенолол никомед табл. п.п.о. 50 мг. №30',
#  717: 'валидол таб.подъяз.60мг №10',
#  718: 'pl рыбий жир капс. №100',
#  719: 'пластырь "cosmos" strips из текстильн. ткани 6х2см 5х50шт арт.530295/1',
#  720: 'эмла крем д/местного и наружн.прим.5% туба 5г №5',
#  721: 'повязка cosmopor e на рану самоклеящаяся стерильная 5 х 7,2см (900870/901008',
#  722: 'ямми турбогематоген детский 30г',
#  723: 'панангин таб.п.п.о.№50',
#  724: 'pl шприц одноразовый инсулиновый 1мл №1',
#  725: 'папаверина гидрохлорид тб 40мг n10',
#  726: 'pl шприц одноразовый 3-комп. 5мл №1',
#  727: 'вестибо таб. 16 мг. №30',
#  728: 'перчатки "peha-soft" латексные н/стерил. без пудры разм. s №2',
#  729: 'нью лайф бинт марл мед стер 5м х 10см уп n1/стм',
#  730: 'pl салфетка антисептическая спиртовая 3х6см №1',
#  731: 'pl контейнер д/биопроб стер. 60мл с крыш и ложкой в инд.уп',
#  732: 'валидол таб.подъяз.60мг №10',
#  733: 'pl шприц одноразовый 3-комп. 2мл №1',
#  734: 'pl шприц одноразовый 3-комп. 5мл №1',
#  735: 'оквис протектор тканей глаза 0,3% фл.5г №1',
#  736: 'диабетон мв тб 60мг n30',
#  737: 'pl хлоргексидин биглюконат р-р 0.05% фл.100мл №1 (ндс 18%',
#  738: 'цефотаксим пор.д/р-ра в/в, в/м фл. 1г',
#  739: 'нью лайф бинт марл мед стер 7м х 14см уп n1/стм',
#  740: 'фосфоглив лиоф д/р-р в/в 2,5г фл./поддон с растворителем №5',
#  741: 'декарис табл. 150 мг. №1',
#  742: 'pl шприц одноразовый инсулиновый 1мл №1',
#  743: 'пульмикорт сусп д/инг 0,25мг/мл контейнер 2мл n20',
#  744: 'фосфалюгель гель 16г n20',
#  745: 'дексаметазон р-р д/ин. 4 мг/мл. амп. 1 мл. №25',
#  746: 'система для переливания инфузионных растворов уп n1',
#  747: 'лейкопластырь бактерицидный 2.3см х 7.2см уп n1',
#  748: 'натрия хлорид 0.9% р-р д/инфуз фл 400мл n1',
#  749: 'pl салфетка антисептическая спиртовая 3х6см №1',
#  750: 'сенаде тб 13.5мг n500',
#  751: 'pl шприц одноразовый 3-комп. 2мл №1',
#  752: 'аллапинин тб 25мг n30',
#  753: 'нормофлорин-b фл 100мл',
#  754: 'парацетамол таб.500мг №10',
#  755: 'pl гематоген 25г',
#  756: 'риностоп капли наз. 0,1% фл. 10мл',
#  757: 'пектусин таб.д/рассас.№10',
#  758: 'ацетилсалициловая кислота таб.500мг №20',
#  759: 'глицин таб.подъяз.100мг №100',
#  760: 'перекись водорода р-р наружн. 3% фл.полимерн. 100мл',
#  761: 'тантум роза р-р вагинальный 0.1% фл.-спринц.140мл с канюлей №5',
#  762: 'ябудужить100лет гематоген спортивный 40г',
#  763: 'парацетамол таб.500мг №10',
#  764: 'катетер игла-бабочка д/вливания в малые вены g22',
#  765: 'ацетилсалициловая кислота тб 500мг n20 renewal',
#  766: 'снуп спрей наз. 0,1% фл.15мл',
#  767: 'янтарная кислота таб.100мг №10/стм',
#  768: 'нью лайф салфетка марл мед стер двухслойн 16см х 14см №10/стм',
#  769: 'pl шприц одноразовый инсулиновый 1мл №1',
#  770: 'немозол таб.п.п.о.400мг №1',
#  771: 'pl хлоргексидин биглюконат р-р 0.05% фл.100мл №1 (ндс 18%',
#  772: 'повязка cosmopor e на рану самоклеящаяся стерильная 6 х 10см (900871/901009',
#  773: 'пустырник настойка фл.25мл',
#  774: 'нормофлорин-d фл 100мл',
#  775: 'бактериофаг стафилококковый жидкий 100мл фл n1',
#  776: 'pl шприц одноразовый 3-комп. 10мл №1',
#  777: 'pl салфетка антисептическая спиртовая 3х6см №1',
#  778: 'бифиформ капс уп n30',
#  779: 'корвалол капли д/приема внутрь 25мл',
#  780: 'pl шприц одноразовый инсулиновый 1мл №1',
#  781: 'нью лайф бинт марл мед стер 7м х 14см уп n1/стм',
#  782: 'нормофлорин-b фл 100мл',
#  783: 'смекта ваниль пор. 3 гр. n10',
#  784: 'нормофлорин-l фл 100мл',
#  785: 'ингавирин капс.90мг №7',
#  786: 'берлитион 600 р-р д/ин. 600 мг/24 мл. амп. 24 мл. №5',
#  787: 'pl шприц одноразовый 3-комп. 5мл №1',
#  788: 'нормофлорин-l фл 100мл',
#  789: 'феррогематоген плитка 50г уп n1',
#  790: 'шприцы одноразовые с иглой 5мл n1',
#  791: 'цефотаксим пор.д/р-ра в/в, в/м фл. 1г',
#  792: 'система трансфуз д/переливания крови, кровезам, инфуз р-ров уп n1',
#  793: 'корвалол капли д/приема внутрь 25мл',
#  794: 'pl хлоргексидин биглюконат р-р 0.05% фл.100мл №1 (ндс 18%',
#  795: 'pl аскорбинка порошок пак.2,5г №1',
#  796: 'pl салфетка антисептическая спиртовая 3х6см №1',
#  797: 'нью лайф салфетка марл мед стер двухслойн 29см х 45см №5/стм',
#  798: 'валосердин капли оралн фл-капел 15мл n1',
#  799: 'уголь активированный тб 250мг n50',
#  800: 'натрия хлорид 0.9% р-р д/инфуз фл 200мл n28',
#  801: 'дексаметазон р-р д/ин. 4 мг/мл. амп. 1 мл. №25',
#  802: 'повязка branolind n стерильная мазевая 10см х 20см n1 арт. 492346',
#  803: 'система для переливания инфузионных растворов уп n1',
#  804: 'кэа хэлс ромашка [цветки фильтр-пакеты 1г] n20',
#  805: 'мастер юни пластырь перцовый 10х18см',
#  806: 'pl аскорбиновая кислота с глюкозой тб 100мг №10',
#  807: 'нафтизин плюс капли назальные 0.1% 15мл n1',
#  808: 'аевит капс n10',
#  809: 'pl салфетка антисептическая спиртовая 3х6см №1',
#  810: 'пакет-сумка бум. 22х31х9см',
#  811: 'омепразол-акрихин капс.кишечнораст.20мг №30',
#  812: 'pl шприц одноразовый 3-комп. 5мл №1',
#  813: 'мочеприемник детский 100мл стер. n1',
#  814: 'нимесил гран.д/приг.суспен.д/приема внутрь 100мг пак.2г №30',
#  815: 'нимесил гран.д/приг.суспен.д/приема внутрь 100мг пак.2г №30',
#  816: 'пенталгин таб.п.п.о.№24 (без кодеина',
#  817: 'траумель с р-р д/и амп 2.2мл №100',
#  818: 'андипал таб.№10',
#  819: 'pl салфетка антисептическая спиртовая 3х6см №1',
#  820: 'аскорбиновая кислота с глюкозой тб 100мг n10',
#  821: 'pl салфетка антисептическая спиртовая 3х6см №1',
#  822: 'салфетки "soft-zellin" спиртовые для инъекций 60мм х 30мм №100',
#  823: 'дискус композитум амп n100',
#  824: 'траумель с р-р д/и амп 2.2мл №100',
#  825: 'нормофлорин-d фл 100мл',
#  826: 'pl шприц одноразовый инсулиновый 1мл №1',
#  827: 'беталок зок таб.п.о.замедл.высв.25мг №14 блистер',
#  828: 'pl шприц одноразовый инсулиновый 1мл №1',
#  829: 'pl салфетка антисептическая спиртовая 3х6см №1',
#  830: 'уголь активированный тб 250мг n10',
#  831: 'pl аскорбинка с сахаром таб. №10',
#  832: 'меновазин раствор д/наружн. применен. спиртовой фл. 40мл',
#  833: 'цель т р-р д/и амп 2,2мл №100',
#  834: 'траумель с р-р д/и амп 2.2мл №100',
#  835: 'коэнзим композитум 2,2мл амп №100',
#  836: 'pl шприц одноразовый 3-комп. 10мл №1',
#  837: 'сенаде тб 13.5мг n500',
#  838: 'дицетел тб п/о 50мг  n20',
#  839: 'цитрамон п таб.№20',
#  840: 'самсон&далила гематоген русский 40г детский',
#  841: 'pl аскорбинка с сахаром таб. №10',
#  842: 'фортранс пор д/оралн р-ра 64г(74г',
#  843: 'pl бинт марл мед стер гост 5м х 10см уп №1',
#  844: 'метрогил р-р для в/в введ.5мг/мл фл.100мл',
#  845: 'нью лайф салфетка марл мед стер двухслойн 16см х 14см №10/стм',
#  846: 'pl салфетка антисептическая спиртовая 13,5х18,5см №1',
#  847: 'дексаметазон р-р д/ин. 4 мг/мл. амп. 1 мл. №25',
#  848: 'pl салфетка антисептическая спиртовая 3х6см №1',
#  849: 'повязка cosmopor e на рану самоклеящаяся стерильная 5 х 7,2см (900870/901008',
#  850: 'дексаметазон р-р д/ин. 4 мг/мл. амп. 1 мл. №25',
#  851: 'корвалол капли д/приема внутрь 25мл',
#  852: 'гидроперит тб 1.5г n8',
#  853: 'нафтизин р-р 0.1% фл/кап 20мл n1',
#  854: 'бинт эласт "peha-haft" когезивный 6см х 4м арт.932423/3',
#  855: 'нью лайф салфетка марл мед стер двухслойн 29см х 45см №5/стм',
#  856: 'pl пластырь бактерицидный влагостойкий воздухопроницаемый 1,9х7,2см №1',
#  857: 'траумель с р-р д/и амп 2.2мл №100',
#  858: 'pl гематоген с кедровым орехом 40г',
#  859: 'pl шприц одноразовый 3-комп. 20мл №1',
#  860: 'система для переливания инфузионных растворов уп n1',
#  861: 'pl шприц одноразовый 3-комп. 10мл №1',
#  862: 'клексан р-р д/инъекций 20мг 0,2мл шпр. №10',
#  863: 'атенолол белупо табл. п.п.о. 50мг n30',
#  864: 'линкомицина гидрохлорид капс.250мг №20',
#  865: 'пикамилон таб.50мг №30',
#  866: 'доксициклин капс 100мг n10',
#  867: 'микстура от кашля для взрослых сухая пор д/оралн р-ра 1.7г пак n1',
#  868: 'нормофлорин-d фл 100мл',
#  869: 'цитрамон п таб.№10',
#  870: 'меновазин раствор д/наружн. применен. спиртовой фл. 40мл',
#  871: 'мастер юни лейкопластырь бактерицидный 6х10см №1',
#  872: 'pl контейнер д/биопроб стер. 60мл с крыш и ложкой в инд.уп',
#  873: 'pl шприц одноразовый 3-комп. 3мл №1',
#  874: 'иглы новофайн 31g (0,25х6мм',
#  875: 'регидрон пор дозир пак 18.9г n20',
#  876: 'слабилен капли 0.75% 15мл фл n1',
#  877: 'регидрон пор дозир пак 18.9г n20',
#  878: 'магний-диаспорал 300 гран.д/пригот.р-ра д/приема внутрь 300мг №50 пакет',
#  879: 'pl шприц одноразовый 3-комп. 5мл №1',
#  880: 'цитрамон п таб.№10',
#  881: 'пульмикорт сусп д/инг 0,5мг/мл контейнер 2мл n20',
#  882: 'сенаде тб 13.5мг n500',
#  883: 'аскорбиновая кислота с глюкозой тб 100мг n10',
#  884: 'pl шприц одноразовый 3-комп. 10мл №1',
#  885: 'pl перчатки нитриловые нестерильные неопудренные р.m 100 пар цветные',
#  886: 'шприц одноразовый sf medical 3-комп.2мл №1/стм',
#  887: 'сенаде тб 13.5мг n500',
#  888: 'pl пластырь бактерицидный влагостойкий воздухопроницаемый 1,9х7,2см №1',
#  889: 'pl шприц одноразовый 3-комп. 5мл №1',
#  890: 'pl пластырь бактерицидный влагостойкий воздухопроницаемый 1,9х7,2см №1',
#  891: 'pl шприц одноразовый 3-комп. 5мл №1',
#  892: 'регидрон пор дозир пак 18.9г n20',
#  893: 'аскорбиновая кислота с глюкозой тб 100мг n10',
#  894: 'пульмикорт сусп д/инг 0,25мг/мл контейнер 2мл n20',
#  895: 'перекись водорода р-р наружн. 3% фл.полимерн. 100мл',
#  896: 'дорзопт капли глазные 2% 5мл. фл.-кап. n3',
#  897: 'меновазин жидк фл 40мл n1',
#  898: 'pl салфетка антисептическая спиртовая 3х6см №1',
#  899: 'pl шприц одноразовый 3-комп. 5мл №1',
#  900: 'пульмикорт сусп д/инг 0,5мг/мл контейнер 2мл n20',
#  901: 'pl шприц одноразовый 3-комп. 2мл №1',
#  902: 'pl салфетка антисептическая спиртовая 3х6см №1',
#  903: 'нимесил гран.д/приг.суспен.д/приема внутрь 100мг пак.2г №30',
#  904: 'pl салфетка антисептическая спиртовая 13,5х18,5см №1',
#  905: 'пульмикорт сусп д/инг 0,5мг/мл контейнер 2мл n20',
#  906: 'лоперамид-акрихин капс.2мг №20',
#  907: 'дексаметазон р-р д/ин. 4 мг/мл. амп. 1 мл. №25',
#  908: 'сенаде тб 13.5мг n500',
#  909: 'цитрамон п таб.№10',
#  910: 'pl сироп шиповника фл.250мл',
#  911: 'салфетка спиртовая для инъекций 3 х 6см',
#  912: 'pl шприц одноразовый 3-комп. 2мл №1',
#  913: 'pl пластырь бактерицидный влагостойкий воздухопроницаемый 1,9х7,2см №1',
#  914: 'повязка cosmopor e на рану самоклеящаяся стерильная 8 х 15см (900874/901021',
#  915: 'лейкопластырь унипласт бактерицидный влагостойкий 2,5 х 7,2см n1',
#  916: 'сенаде тб 13.5мг n500',
#  917: 'пустырник настойка фл.25мл',
#  918: 'повязка cosmopor e на рану самоклеящаяся стерильная 8 х 10см (900873/901020',
#  919: 'дексаметазон р-р д/ин. 4 мг/мл. амп. 1 мл. №25',
#  920: 'pl шприц одноразовый 3-комп. 5мл №1',
#  921: 'дорзопт капли глазные 2% 5мл. фл.-кап. n3',
#  922: 'сенаде тб 13.5мг n500',
#  923: 'pl перчатки латексные нестерильные неопудренные р.l 50 пар',
#  924: 'мастер юни лейкопластырь бактерицидный 6х10см №1',
#  925: 'pl шприц одноразовый 3-комп. 5мл №1',
#  926: 'pl контейнер д/биопроб универс. 120мл полим. с крыш. в инд. уп.',
#  927: 'боярышник [настойка фл 25мл] n1',
#  928: 'повязка cosmopor e на рану самоклеящаяся стерильная 8 х 15см (900874/901021',
#  929: 'тампоны спиртовые soft-zellin 3 х 6см №100 (9999791',
#  930: 'pl шприц одноразовый 3-комп. 2мл №1',
#  931: 'цефтриаксон пор.д/р-ра в/в, в/м фл./пачка 1г',
#  932: 'повязка cosmopor e на рану самоклеящаяся стерильная 8 х 10см (900873/901020',
#  933: 'pl шприц одноразовый 3-комп. 3мл №1',
#  934: 'pl пластырь бактерицидный влагостойкий воздухопроницаемый 1,9х7,2см №1',
#  935: 'нью лайф салфетка марл мед стер двухслойн 29см х 45см №5/стм',
#  936: 'немозол таб.п.п.о.400мг №1',
#  937: 'дилтиазем ланнахер тб п/о ретард 90мг бл n20',
#  938: 'натрия хлорид 0.9% р-р д/инфуз фл 400мл n1',
#  939: 'риностоп капли наз. 0,05% фл. 10мл',
#  940: 'сенаде тб 13.5мг n500',
#  941: 'сотагексал тб 80мг бл n20',
#  942: 'шприц одноразовый 3мл 3-компонентный с иглой 0,6х30мм №1',
#  943: 'боярышник [настойка фл 25мл] n1',
#  944: 'валериана [настойка фл 25мл] n1',
#  945: 'платки носовые "зева делюкс ромашка" №10',
#  946: 'салфетка спиртовая для инъекций 3 х 6см',
#  947: 'пластырь "cosmos" strips из текстильн. ткани 6х2см №5',
#  948: 'pl гематоген 25г',
#  949: 'сенаде тб 13.5мг n500',
#  950: 'pl шприц одноразовый 3-комп. 3мл №1',
#  951: 'дицинон р-р для в/в и в/м введ.125мг/мл амп. 2мл №50',
#  952: 'pl шприц одноразовый 3-комп. 2мл №1',
#  953: 'pl пластырь бактерицидный влагостойкий воздухопроницаемый 1,9х7,2см №1',
#  954: 'нимесил гран.д/приг.суспен.д/приема внутрь 100мг пак.2г №30',
#  955: 'pl шприц одноразовый 3-комп. 10мл №1',
#  956: 'повязка cosmopor e на рану самоклеящаяся стерильная 5 х 7,2см (900870/901008',
#  957: 'токоферола ацетат капс.100мг №10',
#  958: 'клексан р-р д/инъекций 40мг 0,4мл шпр. №10',
#  959: 'сенаде тб 13.5мг n500',
#  960: 'дексаметазон р-р д/ин. 4 мг/мл. амп. 1 мл. №25',
#  961: 'pl пластырь бактерицидный влагостойкий воздухопроницаемый 1,9х7,2см №1',
#  962: 'дицинон таб.250мг №100',
#  963: 'дицинон таб.250мг №100',
#  964: 'нимесил гран.д/приг.суспен.д/приема внутрь 100мг пак.2г №30',
#  965: 'pl салфетка антисептическая спиртовая 3х6см №1',
#  966: 'дорзопт капли глазные 2% 5мл. фл.-кап. n3',
#  967: 'нимесил гран.д/приг.суспен.д/приема внутрь 100мг пак.2г №30',
#  968: 'pl пластырь бактерицидный влагостойкий воздухопроницаемый 1,9х7,2см №1',
#  969: 'маалокс сусп.д/приема внутрь пак.15мл №30',
#  970: 'риностоп капли наз. 0,1% фл. 10мл',
#  971: 'нимесил гран.д/приг.суспен.д/приема внутрь 100мг пак.2г №30',
#  972: 'нью лайф бинт марл мед н/стер 5м х 10см уп n1/стм',
#  973: 'актовегин р-р д/ин. 40 мг/мл. амп. 2 мл. №25',
#  974: 'сенаде тб 13.5мг n500',
#  975: 'дексаметазон р-р д/ин. 4 мг/мл. амп. 1 мл. №25',
#  976: 'фортранс пор д/оралн р-ра 64г(74г',
#  977: 'pl пластырь бактерицидный влагостойкий воздухопроницаемый 1,9х7,2см №1',
#  978: 'актовегин р-р д/ин. 40 мг/мл. амп. 2 мл. №25',
#  979: 'энтеросгель паста д/приема внутрь туба 225 гр.',
#  980: 'нимесил гран.д/приг.суспен.д/приема внутрь 100мг пак.2г №30',
#  981: 'мастер юни пластырь перцовый 10х18см',
#  982: 'повязка cosmopor e на рану самоклеящаяся стерильная 8 х 10см (900873/901020',
#  983: 'pl перчатки нитриловые нестерильные неопудренные р.m 100 пар цветные',
#  984: 'сенаде тб 13.5мг n500',
#  985: 'лейкопластырь унипласт бактерицидный влагостойкий 2,5 х 7,2см n1',
#  986: 'маалокс сусп.д/приема внутрь пак.15мл №30',
#  987: 'тримедат таб. 200мг № 30',
#  988: 'витатека пластырь перцовый перфорированный 10х18см №1',
#  989: 'pl шприц одноразовый 3-комп. 3мл №1',
#  990: 'сенаде тб 13.5мг n500',
#  991: 'регидрон пор дозир пак 18.9г n20',
#  992: 'pl пластырь бактерицидный влагостойкий воздухопроницаемый 1,9х7,2см №1',
#  993: 'клексан р-р д/инъекций 80мг 0,8мл шпр. №10',
#  994: 'пульмикорт сусп д/инг 0,25мг/мл контейнер 2мл n20',
#  995: 'pl шприц одноразовый 3-комп. 5мл №1',
#  996: 'лейкопластырь унипласт бактерицидный влагостойкий 2,5 х 7,2см n1',
#  997: 'сенаде тб 13.5мг n500',
#  998: 'сенаде тб 13.5мг n500',
#  999: 'дорзопт капли глазные 2% 5мл. фл.-кап. n3',
#  ...}

# %%
modelWV = Word2Vec.load('./model/modelWV')
threshold = 0.02
def find_answer(question):
    preprocessed_question = preprocess_txt(question)
    n_w2v = 0
    vector = np.zeros(20)
    for word in preprocessed_question:
        if word in modelWV.wv:
            vector += modelWV.wv[word]
            n_w2v += 1
    if n_w2v > 0:
        vector = vector / n_w2v
    
    answer_index = indexProduct.get_nns_by_vector(vector, 5, include_distances=True)
    
    
    asnwer = {}
    
    index = answer_index[0]
    distance = answer_index[1]
    for index, item in enumerate(index):
        productName = index_product[item]
        productId = index_itemId[item]
            
        asnwer[productId] = productName

    return asnwer

# %%
find_answer('одноразовый')
# Out:
# ([2334568, 16524126, 2341561, 2845148, 2923780], [0.7231814861297607, 0.7410405874252319, 0.7609788775444031, 0.7609788775444031, 0.7609788775444031])
# {'192163': 'шприц одноразовый 10мл 3-компонентный с иглой 0,8х40мм №1',
#  '38826': 'шприцы одноразовые с иглой 0,8х40мм 20мл уп n1',
#  '192162': 'шприц одноразовый 5мл 3-компонентный с иглой 0,7х40мм №1'}

# %% [markdown]
# ### Реализуем функцию выбора пакета

# %%
dataPacket = pd.DataFrame()
dataAll = pd.DataFrame()
def getrandomPasket():
    dataPacket = dataTransform[(dataTransform['itemName'].str.startswith("пакет-майка"))]
    
    ItemIgnore = set(list(dataPacket['itemId'].values))
    dataPacket.drop_duplicates(['itemId'], keep='first', inplace=True)    
    
    dataAll = dataTransform[~dataTransform['itemId'].isin(list(ItemIgnore))]
    
    return  dataPacket , dataAll

# %%
dataPacket , dataAll = getrandomPasket()
# Out:
# c:\study\venv\lib\site-packages\pandas\util\_decorators.py:311: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return func(*args, **kwargs)

# %%
dataPacket
# Out:
#          user_id  itemId                 itemName                      text
# 0        1260627  197312  пакет-майка 25см х 45см  [пакет, майк, 25смx45см]
# 4777167  1786235  200394  пакет-майка 40см х 70см  [пакет, майк, 40смx70см]

# %% [markdown]
# Логика рекомнедации такая
#
#  1 Если есть есть номер клиента - предложим ему из того что он раньше покупил (2 товара)
#    Предложим ему из 1000 самых популярны товаров
#
#  2. Если есть название - предлождим товера по названию
#
#  3. В конце предложить пакет

# %%
#  функция преложение пользователю того что он покупал ранее
def userOldBuy(userId = None):
    userBuy = dataTransform[dataTransform['user_id'] == int(userId)].copy()
    popularUser = userBuy['itemId'].value_counts().rename_axis('itemId').reset_index(name='counts')
    userItems = rnd.choices(list(popularUser['itemId']), k=3)
    popular = dataTransform[dataTransform['itemId'].isin(userItems)].drop_duplicates(['itemId'], keep='first')

    userOldBuy = {}
    for index, row in popular.iterrows():
        userOldBuy[row['itemId']] = row['itemName']
    return userOldBuy
# функция предожения самог опопулярного товаров
def userPopular(userId =None):
    Popular = generatorUser(userID =userId )

    usersPopular = {}
    for item in Popular:
        posible = dataTransform[dataTransform['itemName'] == item]
        if not posible.empty:
            usersPopular[posible.iloc[0]['itemId']] = posible.iloc[0]['itemName']
    return usersPopular

# функция выбора пакета
def packerChoose():
    paketsDict = {}
    pakets = rnd.choices((dataPacket['itemId'].values), k=1)
    paketsChoose =  dataPacket[dataPacket['itemId'] == pakets[0]]

    itemId = paketsChoose.iloc[0]['itemId']
    itemName = paketsChoose.iloc[0]['itemName'] 
    paketsDict[itemId] = itemName
    return paketsDict
#  выбор по запросу
def requestuser(Request = ''): 
    answers = find_answer('одноразовый')

    requestDict = {}
    for index, item in answers.items():
        userSeg  = dataTransform[dataTransform['itemName'] == item].drop_duplicates(['itemId'], keep='first')
    
        if not userSeg.empty:
            itemId = userSeg.iloc[0]['itemId']
            itemName = userSeg.iloc[0]['itemName'] 
            answers[itemId] = itemName
    return answers

# %%
def recomendUser(userId = None, request = None):
    segeust = packerChoose()
    if userId != None:
        userBuy = userOldBuy(userId)
        userPop = userPopular(userId)        
        segeust.update(userBuy)
        segeust.update(userPop)
        
    if request != None:
        requestUser = requestuser(request)
        segeust.update(requestUser)
    return segeust

# %%
recomendUser(userId = 1786235, request= 'одноразовый')
# Out:
# {'200394': 'пакет-майка 40см х 70см',
#  '62968': 'перекись водорода р-р наружн. 3% фл.полимерн. 100мл',
#  '45112': 'присыпка детская 40г уп n1',
#  '70458': 'пенталгин таб.п.п.о.№24 (без кодеина',
#  '118125': 'кардиомагнил таб.п.п.о.75мг №100',
#  '60684': 'тенотен детский таб. №40',
#  '192163': 'шприц одноразовый 10мл 3-компонентный с иглой 0,8х40мм №1',
#  '38826': 'шприцы одноразовые с иглой 0,8х40мм 20мл уп n1',
#  '192162': 'шприц одноразовый 5мл 3-компонентный с иглой 0,7х40мм №1'}

# %% [markdown]
# Вывод:
#
#     была рассмотрена системе рекомендации - применена колаборативная фильтрация для наиболее популярных товаров
#     а также построена модель Word2Vec для поиска похожих по названию товаров
#
# Вадидацинный сет применять как уже писал ненужна - нет информации о покупке преложенных товаров а сами пользоватедли
# представлены в модели в единичном экзепмпляре (была одна покупка - по одному значению распределение не построишь!)
#
# Из слоожного  - уж больно долго было обрабатывать датасет из почти 20 млн строк  - у меня два раза ломался
# ноутбук (приходилось все перстараивать а это в примерно 7-8 часов)
